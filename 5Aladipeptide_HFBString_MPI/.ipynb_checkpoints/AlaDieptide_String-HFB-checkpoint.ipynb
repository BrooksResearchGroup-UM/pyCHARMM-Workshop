# %% [markdown]
# # String Method for Free Energy Pathway Sampling
# <div class="alert alert-block alert-info">
#     <b>Note:</b> This notebook uses ipyparallel and mpi4py for parallel distribution of string beads. It takes about 20 minutes to complete running interactively on an 8-core Intel 2.3 GHz processor MacBookPro using 8 parallel tasks and the parameters specified below.</div>
#
# ## <u>Objective</u>
# > ## Construct the minimum (free) energy path for transitions between two distinct states of a biopolymer using the Harmonic Fourier Bead String method.
# ## <u>Citation</u>
# > ### IV Khavrutskii, K Arora and CL Brooks III. Harmonic Fourier beads method for studying rare events on rugged energy surfaces. *J Chem Phys*, **2006**, 125:174108.
#
# ## This example uses the the simple blocked alaninie dipeptide and searches the (free) energy landscape to find the minimum (free) energy pathway between the two endpoint conformations.
# ## We carry-out the search in this example using the simple vacuum surface and energy minimization. Therefore, we are finding the minimum energy pathway. However, the minimum free energy pathway can also be found if we use molecular dynamics at a given temperature to sample the free energy path.
# ## <u>Options in this notebook cover:</u>
# > ##  - String with vacuum surface using minimization or MD
# > ##  - String with GBMV implicit solvent surface using minimization or MD
# > ##  - String with explicit solvent using MD
# ## Set-up parallel stuff specifying 8 processes to manage our 32 beads in the string calculation.

# %%
import ipyparallel as ipp
cluster = ipp.Cluster(engines="MPI",n=8)
cluster.start_and_connect_sync()
# Out:
# Starting 8 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/8 [00:00<?, ?engine/s]

# %% [markdown]
# ## 1. Set-up needed python libraries and MPI
# ## 2. Fix parameters for this specific calculation
# <div class="alert alert-block alert-info">
#     <b>Note:</b> We use ipyparallel "magics" (<i>%%px</i>) to enable parallel execution of the cell blocks</div>

# %%
# %%px
# # This script implements a sting path optimization using HFB and
# # plots the progress on the alanine dipeptide phi/psi (f/y) map using pyCHARMM
# # Written by C.L. Brooks III, November 10, 2020
#
# import os
# import sys
# import subprocess
# import numpy as np
# import pandas as pd
# import shlex
#
# from pycharmm import *
# import pycharmm
#
# # Now we will loop over beads, w/ each bead assigned to
# # a a computational node, where node = rank in python mpi
# # set up a communicator and get the rank of this process
# # Global variables
# # Add in mpi support
# from mpi4py import MPI
# comm = MPI.COMM_WORLD
# nproc = comm.Get_size()
# rank = comm.Get_rank()
#
# gpusperproc = 1  # number of gpus available on each node, should match nproc
# nbeads = 32  # We'll do a path with 32 beads
# firststep = 0
# nsteps = 2001 #2001
# update = 250  #500
# # This parameter should be 1 when one is generating the first pass of the string path
# # values greater than 1 jump along an existing path and display the evolution every skip
# # steps.
# skip = 1    #500
# inter = True # make interactive plots of progress
# gbmv = False  #False
# usemd = False
# useomm = False
# nstep = 1000
# nsavc = 100
# if gbmv:   # For use with implicit solvent
#     path = 'gbmv'
#     apnd = '_gbmv'
# else:      # For vacuum runs
#     path = 'vacuum'
#     apnd = ''
# # template for f/y restraints
# Fcons = '1 CY 1 N 1 CA 1 C'
# Ycons = '1 N 1 CA 1 C 1 NT'
# Out:
# %px:   0%|          | 0/8 [00:00<?, ?tasks/s]

# %% [markdown]
# ## The subsequent cell contains a number of working functions defined to enable the scripting of the HFB string calculation.
# <div class="alert alert-block alert-info">
#     <b>Note:</b> We use ipyparallel "magics" (<i>%%px</i>) to enable parallel execution of the cell blocks</div>

# %%
# %%px
# def set_beta(beta):
#     n = psf.get_natom()
#     fbetas = [0.0] * n
#     for i, v in enumerate(SelectAtoms(hydrogens=True)):
#         if not v:
#             fbetas[i] = beta
#
#     dyn.set_fbetas(fbetas)
#
# def evolve_String(ibead,istep):
#     # turn off the noise
#     # Evolve each bead by minimization
#     trj = charmm_file.CharmmFile(f'{path}/dcd_evolve/refine_{istep}.dcd',
#                            file_unit=1,
#                            formatted=False,
#                            read_only=True)
#     traj_read = f'''
#     traj firstunit {trj.file_unit} nunit 1 begin {ibead+1}
#     traj read'''
#     lingo.charmm_script(traj_read)
#     write.coor_pdb(f'{path}/pdb_evolve/refine_{ibead}-{istep}.pdb')
#     trj.close()
#     cons_harm.setup_absolute(force_const = 10,
#                               q_mass=True,
#                              selection=RCS)
#     if not usemd: minimize.run_abnr(nstep=1000,
#                                      tolenr=1e-3,
#                                      tolgrd=1e-3)
#     if gbmv:
#         opl = settings.set_verbosity(0)
#         read.stream(../toppar/radii_c36gbmvop.str)
#         settings.set_verbosity(opl)
#         script.CommandScript('gbmv', beta=-12, p3=0.65, watr=1.4, shift=-0.102,slope=0.9085,
#                              p6=8, sa=0.005, wtyp=2, nphi=38, cutnum=100, kappa=0, weight=True).run()
#     if not usemd: minimize.run_abnr(nstep=500,
#                                          tolenr=1e-3,
#                                          tolgrd=1e-3)
#     if usemd:
#         if useomm: lingo.charmm_script(f'omm deviceid {ibead % gpusperproc}')
#         dcd = charmm_file.CharmmFile(f'dcd/evolve_{ibead}.dcd',
#                                      file_unit=1,
#                                      formatted=False,
#                                      read_only=False)
#         ommdyn = ''
#         if useomm: ommdyn = 'omm gamma 5'
#         else: set_beta(5)
#         dynamics = DynamicsScript(lang=True,start=True,timest=0.002,
#                                            nstep=nstep,finalt=298,tstru=298,
#                                            firstt=298,tbath=298,inbfrq=-1,imgfrq=-1,
#                                            bygr=True,iasors=1,iasvel=1,ntrfrq=nstep,
#                                            nprint=2*nsavc,iprfrq=nsavc,nsavc=nsavc,
#                                            nsavv=0,isvfrq=nsavc,iunvel=-1,kunit=-1,
#                                            iunwri=0,iuncrd=dcd.file_unit,
#                                            omm=ommdyn)
#         shake.on(param=True,tol=1e-7,bonh=True)
#         dynamics.run()
#         shake.off()
#         if useomm: lingo.charmm_script('omm off')
#         dcd.close()
#         dcd = charmm_file.CharmmFile(f'dcd/evolve_{ibead}.dcd',
#                                      file_unit=1,
#                                      formatted=False,
#                                      read_only=True)
#         lingo.charmm_script(f'coor dyna firstu {dcd.file_unit} nunit 1')
#         dcd.close()
#
#     cons_harm.turn_off()
#     if gbmv: lingo.charmm_script('gbmv clear')
#     write.coor_pdb(f'{path}/pdb_evolve/evolve_{ibead}-{istep}.pdb')
#     return
# def getRMSD(pdbold,pdbnew,select):
#     read.pdb(pdbold,resid=True)
#     # 'coor copy compare'
#     xyzcomp = coor.get_positions()
#     #xyzcomp.columns=['xcomp','ycomp','zcomp']
#     xyzcomp['w']=xyzcomp.x
#     coor.set_comparison(xyzcomp)
#     read.pdb(pdbnew,resid=True)
#     coor.orient(rms=True,mass=False,noro=False,selection=select)
#     return pycharmm.lingo.get_energy_value('RMS')
# def getFY(F,Y):
#     lingo.charmm_script(f'q {F}')
#     f = lingo.get_energy_value('PHI')
#     lingo.charmm_script(f'q {Y}')
#     y = lingo.get_energy_value('PHI')
#     return (f,y)
# def pltFY(F,Y,F0,Y0,istep,rmsd):
#     import pickle
#     with open(f'fy_maps/fymap-ala{apnd}.pkl', 'rb') as fh:
#         fymap = pickle.load(fh)
#     emax = np.max(fymap['ener'])
#     emin = np.min(fymap['ener'])
#     erange = emax - emin
#     ehigh = np.ceil(emin+1.1*erange)
#     elow = np.floor(emax-1.1*erange)
#     contours = np.linspace(elow,ehigh,12)
#     f,y = np.meshgrid(fymap['F'],fymap['Y'])
#     %matplotlib inline
#     from mpl_toolkits.mplot3d import Axes3D
#     import matplotlib.pyplot as plt
#     from matplotlib import cm
#     from matplotlib.ticker import LinearLocator, FormatStrFormatter
#     plt.rcParams.update({'font.size':12})
#     fig = plt.figure(figsize=(4,3))
#     left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
#     ax = fig.add_axes([left, bottom, width, height])
#     cp = plt.contourf(f, y, fymap['ener'],contours)
#     plt.colorbar(cp)
#     plt.scatter(F,Y,c='k',s=10)
#     print('Plotting at step {}'.format(istep))
#     if istep == nsteps-1:
#         print('Plotting last data')
#         plt.scatter(F0,Y0,c='r',s=10)
#         ax.set_title(rf'String positions from steps 0 and {istep}.\nRMSD at step {istep}: {rmsd:4.2f} $\AA$')
#     else:
#         ax.set_title(rf'String position and RMSD at step {istep}: {rmsd:4.2f} $\AA$')
#     ax.set_xlabel(r'$\phi$')
#     ax.set_ylabel(r'$\psi$')
#     #if istep == nsteps - 1:
#     plt.savefig(f'{path}/alad_string{apnd}-{istep}.pdf')
#     if inter: plt.show()
#     return
#
# def selectRCS():
#     # This function creates a selection array rcs for the specific system
#     # of interest reaction coordinates
#     # This selection process needs to be altered depending on
#     # the system of interest.
#     # Define the RCS using this selection process
#     atoms = ['CY', 'N', 'CA', 'C','NT']
#     atom = SelectAtoms()
#     if rank == 0: print('RCS selected',np.sum(list(atom)),'atom')
#     for i in atoms:
#         atom.by_res_and_type('ALAD','1',i)
#         if rank == 0: print('RCS selected',np.sum(list(atom)),'atoms')
#     rcs = atom and ( SelectAtoms(seg_id='ALAD') and SelectAtoms(res_id='1') )
#     if rank == 0: print('RCS selected',np.sum(list(rcs)),'atoms')
#
#     return rcs
# def minFY_abnr(Fcons,Ycons,f,y):
#     # generate initial F/Y endpoints and use HFB to interpolate
#     cons_methods.dihe(selection=Fcons, force=1000, minimum=f)
#     cons_methods.dihe(selection=Ycons, force=1000, minimum=y)
#     minimize.run_abnr(**{'nstep': 1000,
#                        'tolenr': 1e-3,
#                        'tolgrd': 1e-3})
#     cons_methods.dihe(cldh=True)
#     return
# def init_hfbrun():
#     # Generate two F/Y endpoint structures
#     # Now gather beads and update with HFB
#     if not os.path.isdir('pdb'): os.system('mkdir pdb')
#     if gbmv: minFY_abnr(Fcons,Ycons,-100,160)
#     else: minFY_abnr(Fcons,Ycons,-70,70)
#     write.coor_pdb('pdb/ad_begin.pdb')
#     write.coor_card('pdb/ad_begin.chr',title='Beginning Coordinates')
#     if gbmv: minFY_abnr(Fcons,Ycons,-100,30)
#     else: minFY_abnr(Fcons,Ycons,0,20)
#     write.coor_pdb('pdb/ad_mid.pdb')
#     write.coor_card('pdb/ad_mid.chr',title='Mid-point Coordinates')
#     if gbmv: minFY_abnr(Fcons,Ycons,70,-110)
#     else: minFY_abnr(Fcons,Ycons,60,-60)
#     write.coor_pdb('pdb/ad_end.pdb')
#     write.coor_card('pdb/ad_end.chr',title='End-point Coordinates')
#     # Make initial path using HFB
#     if not os.path.isdir(f'{path}'.format(path)):
#         os.system(f'mkdir -p {path}/dcd_evolve')
#         os.system(f'mkdir -p {path}/pdb_evolve')
#     if not os.path.isdir('cpr'): os.system('mkdir cpr')
#     hfb_init = f'''
#     define rcs select type n .or. type c .or. type ca -
#     .or. type nt .or. type cy end
#     trek maxpoint {nbeads} select rcs end mass
#     traj read
#        pdb/ad_begin.chr
#        pdb/ad_mid.chr
#        pdb/ad_end.chr
#     done
#     fp trnc 24 init
#     traj write name {path}/dcd_evolve/refine_{0}.dcd restart cpr/diala.cpr
#     quit'''
#     lingo.charmm_script(hfb_init)
#     return

# %% [markdown]
# ## Set-up system, establish our endpoints for the string calculation and the first string

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Note:</b> We use ipyparallel "magics" (<i>%%px</i>) to enable parallel execution of the cell blocks</div>

# %%
# %%px
# #####################################################################
# ###############PYCHARMM SCRIPTING STARTS HERE########################
# if rank != 0: settings.set_verbosity(0)
# settings.set_warn_level(-4)
# read.rtf('toppar/top_all36_prot.rtf')
# read.prm('toppar/par_all36_prot.prm')
# read.sequence_string('ALA')
# gen.new_segment(seg_name='ALAD',
#                     first_patch='ACE',
#                     last_patch='CT3',
#                     setup_ic=True)
# RCS = selectRCS()
# ic.prm_fill(replace_all=True)
# ic.seed(1,'CAY',1,'CY',1,'N')
# ic.build()
# nb_vac = pycharmm.NonBondedScript(cutnb = 16,
#                   ctofnb = 14,
#                   ctonnb = 12,
#                   atom = True,
#                   vatom = True,
#                   eps = 1,
#                   switch = True,
#                   vswitch = True,
#                   cdie = True)
# nb_vac.run()
# comm.barrier()
# if rank == 0 and not os.path.exists('pdb/ad_begin.chr'):
#     settings.set_verbosity(0)
#     init_hfbrun()
#     settings.set_verbosity(5)
# comm.barrier() # Need to wait for all processors
# Out:
# [stdout:0]
#  CHARMM>     read rtf card -
#  CHARMM>     name toppar/top_all36_prot.rtf
#  VOPEN> Attempting to open::TOPPAR/TOP_ALL36_PROT.RTF::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> *>>>>>>>>CHARMM36 ALL-HYDROGEN TOPOLOGY FILE FOR PROTEINS <<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> MAY 2011 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name toppar/par_all36_prot.prm
#  VOPEN> Attempting to open::TOPPAR/PAR_ALL36_PROT.PRM::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> *>>>> CHARMM36 ALL-HYDROGEN PARAMETER FILE FOR PROTEINS <<<<<<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> FEB. 2012 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#           RESIDUE SEQUENCE --     1 RESIDUES
#           ALA
#  THE PATCH 'ACE' WILL BE USED FOR THE FIRST RESIDUE
#  THE PATCH 'CT3' WILL BE USED FOR THE LAST  RESIDUE
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  GENPSF> Segment   1 has been generated. Its identifier is ALAD.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =        1
#          Number of atoms         =       22   Number of groups     =        6
#          Number of bonds         =       21   Number of angles     =       36
#          Number of dihedrals     =       41   Number of impropers  =        4
#          Number of cross-terms   =        0   Number of autogens   =        0
#          Number of HB acceptors  =        2   Number of HB donors  =        2
#          Number of NB exclusions =        0   Total charge =    0.00000
# RCS selected 0 atom
# RCS selected 1 atoms
# RCS selected 2 atoms
# RCS selected 3 atoms
# RCS selected 4 atoms
# RCS selected 5 atoms
# RCS selected 22 atoms
#
#  CHARMM>     nbonds cutnb 16 -
#  CHARMM>     ctofnb 14 -
#  CHARMM>     ctonnb 12 -
#  CHARMM>     atom -
#  CHARMM>     vatom -
#  CHARMM>     eps 1 -
#  CHARMM>     switch -
#  CHARMM>     vswitch -
#  CHARMM>     cdie
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  SWITch   VATOm    VSWItch
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 16.000 CTEXNB =999.000 CTONNB = 12.000 CTOFNB = 14.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found     57 exclusions and     41 interactions(1-4)
#  <MAKGRP> found     11 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR      221 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#       174 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#
#  CHARMM>
#
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>        traj read
#
#                    pdb/ad_begin.chr
#  VOPEN> Attempting to open::PDB/AD_BEGIN.CHR::
#  OPNLGU> Unit 40 opened for READONLY access to PDB/AD_BEGIN.CHR
#           SPATIAL COORDINATES BEING READ FROM UNIT 40
#  TITLE> * BEGINNING COORDINATES
#  TITLE> *  DATE:     1/13/23     18:15:38      CREATED BY USER: BROOKSCL
#  TITLE> *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#                    pdb/ad_mid.chr
#  VOPEN> Attempting to open::PDB/AD_MID.CHR::
#  OPNLGU> Unit 40 opened for READONLY access to PDB/AD_MID.CHR
#           SPATIAL COORDINATES BEING READ FROM UNIT 40
#  TITLE> * MID-POINT COORDINATES
#  TITLE> *  DATE:     1/13/23     18:15:38      CREATED BY USER: BROOKSCL
#  TITLE> *
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#                    pdb/ad_end.chr
#  VOPEN> Attempting to open::PDB/AD_END.CHR::
#  OPNLGU> Unit 40 opened for READONLY access to PDB/AD_END.CHR
#           SPATIAL COORDINATES BEING READ FROM UNIT 40
#  TITLE> * END-POINT COORDINATES
#  TITLE> *  DATE:     1/13/23     18:15:38      CREATED BY USER: BROOKSCL
#  TITLE> *
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#                 done
#
# Number of starting Path-Points: NPOINT =            3
#
#    TReK>        fp trnc 24 init
# Performing line interpolation
# Interpolating between points:            1            2
# Increasing the numb. of points by interpolating
# The new total number of path-points NPOINT =           32
#
#    TReK>        traj write name vacuum/dcd_evolve/refine_0.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_0.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_0.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>        quit

# %% [markdown]
# ## Now we can visualize the starting configurations using the *pymol -R &* trick.
# ## In a terminal window start a pymol with *pymol - R &*

# %%
# %%px
# # if you can run pymol in your setup issue the command above in the terminal and set the usepymol logical
# # here:
# usepymol = True
# if usepymol and rank == 0:
#     import xmlrpc.client as xmlrpclib
#     cmd = xmlrpclib.ServerProxy('http://localhost:9123')
#     cmd.reinitialize()
#     # We can use this command interface to alter the view/representation and selection
#     !ls
#     cmd.load('pdb/ad_begin.pdb')
#     cmd.load('pdb/ad_mid.pdb')
#     cmd.load('pdb/ad_end.pdb')
#     !ls pdb
# comm.barrier
# # Otherwise set usepymol to False and proceed.
# Out:
# Out[2:4]: <function Intracomm.barrier>
# Out[1:4]: <function Intracomm.barrier>
# Out[3:4]: <function Intracomm.barrier>
# Out[4:4]: <function Intracomm.barrier>
# Out[5:4]: <function Intracomm.barrier>
# Out[6:4]: <function Intracomm.barrier>
# Out[7:4]: <function Intracomm.barrier>
# [stdout:0] SETTING-UP CHARMM
# pyCHARMM w/o MPI library present, set CHARMM_LIB_DIR
# pyCHARMM w MPI library present, set CHARMM_LIB_DIR_mpi
# CHARMM present, set charmm
# Setting up MMSTB Tools
# Setting up MATCH
# Setting up BABEL stuff
# Setting up chimera
# Adding chemaxon
# Adding ssh agents
# Past case statement
# Past orca
# AlaDieptide_String-HFB.ipynb script
# cpr                          toppar
# fy_maps                      vacuum
# pdb
# SETTING-UP CHARMM
# pyCHARMM w/o MPI library present, set CHARMM_LIB_DIR
# pyCHARMM w MPI library present, set CHARMM_LIB_DIR_mpi
# CHARMM present, set charmm
# Setting up MMSTB Tools
# Setting up MATCH
# Setting up BABEL stuff
# Setting up chimera
# Adding chemaxon
# Adding ssh agents
# Past case statement
# Past orca
# ad_begin.chr ad_begin.pdb ad_end.chr   ad_end.pdb   ad_mid.chr   ad_mid.pdb
# %px:   0%|          | 0/8 [00:00<?, ?tasks/s]
# Out[0:4]: <function Intracomm.barrier>

# %%
# %%px
# F = []
# Y = []
# RMS = []
# for istep in range(firststep,nsteps,skip):
#     for ibead in range(nbeads):
#         if not (ibead % nproc == rank): continue
#         if rank == 0: settings.set_verbosity(0)
#         evolve_String(ibead,istep)
#         if rank == 0: settings.set_verbosity(5)
#     comm.barrier()
#     if rank == 0:
#         settings.set_verbosity(0)
#         # Now gather beads and update with HFB
#         trj = charmm_file.CharmmFile(
#             file_name=f'{path}/dcd_evolve/evolve_{istep}.dcd',
#             file_unit=2,
#             formatted=False,
#             read_only=False)
#         traj_write = f'''
#         traj iwrite {trj.file_unit} nwrite 1 nfile {nbeads}
#         '''
#         lingo.charmm_script(traj_write)
#
#         for ibead in range(nbeads):
#             read.pdb(f'{path}/pdb_evolve/evolve_{ibead}-{istep}.pdb')
#             pycharmm.lingo.charmm_script('traj write')
#         trj.close()
#         hfb_refine = f'''
#         define rcs select type n .or. type c .or. type ca -
#            .or. type nt .or. type cy end
#         trek maxpoint {nbeads} select rcs end mass
#         traj read name {path}/dcd_evolve/evolve_{istep}.dcd begin 1 skip 1
#         !traj read name {path}/dcd_evolve/refine_{istep}.dcd begin 1 skip 1
#         fp trnc 24
#         !wrkp trnc 24 bead {nbeads} grid {nbeads*2} rtyp 1 rfrc 10.0 step 0.00125
#         traj write name {path}/dcd_evolve/refine_{istep+1}.dcd restart cpr/diala.cpr
#         quit'''
#         lingo.charmm_script(hfb_refine)
#         if istep % update == 0:
#             settings.set_verbosity(0)
#             trj = charmm_file.CharmmFile(
#                 file_name=f'{path}/dcd_evolve/refine_{istep+1}.dcd'.format(path,istep+1),
#                 file_unit=1,
#                 formatted=False,
#                 read_only=True)
#             traj_read = f'''
#             traj firstunit {trj.file_unit} nunit 1
#             '''
#             pycharmm.lingo.charmm_script(traj_read)
#             rmstot = 0.0
#             for ibead in range(nbeads):
#                 pycharmm.lingo.charmm_script('traj read')
#                 write.coor_pdb(f'{path}/pdb_evolve/refine_{ibead}-{istep}.pdb')
#                 rmstot += getRMSD(f'{path}/pdb_evolve/refine_{ibead}-0.pdb',
#                                   f'{path}/pdb_evolve/refine_{ibead}-{istep+1}.pdb',select=RCS)
#                 f,y = getFY(Fcons,Ycons)
#                 F.append(f)
#                 Y.append(y)
#             RMS.append(rmstot/nbeads)
#             print(f'Average RMS from step {istep} to step {istep+1} is {RMS[-1]:5.3f}')
#             print('Length of RMS',len(RMS))
#             if len(RMS) == 1:
#                 pltFY(np.asarray(F),
#                       np.asarray(Y),
#                       np.asarray(F),
#                       np.asarray(Y),
#                       istep,
#                       RMS[-1])
#             else:
#                 print(f'Reshaping ({len(RMS)},{nbeads})')
#                 pltFY(np.reshape(np.asarray(F),(len(RMS),nbeads))[-1,:],
#                       np.reshape(np.asarray(Y),(len(RMS),nbeads))[-1,:],
#                       np.reshape(np.asarray(F),(len(RMS),nbeads))[0,:],
#                       np.reshape(np.asarray(Y),(len(RMS),nbeads))[0,:],
#                       istep,
#                       RMS[-1])
#             print(f'Finished step {istep}')
#         settings.set_verbosity(5)
#     comm.barrier()
# comm.barrier()
# Out:
# %px:   0%|          | 0/8 [00:00<?, ?tasks/s]
# [stdout:0]
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_0.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_0.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_0.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:41      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_0.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_1.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_1.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_1.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
# A selection has been stored as YYKKQYDWXVLTVEQPBTMB
# A selection has been stored as SIOQWCIVKVAQJTTTGNCE
# A selection has been stored as WGYPHPQYBXQXXUNRCPVP
# A selection has been stored as EKEVKVWPUTQYMPVPXRCS
# A selection has been stored as GHRTVGYRDUAZAHVHBXDG
# A selection has been stored as UPSKIDXCBCCLYLLXTXTK
# A selection has been stored as KVJEPCMTMEGJXAFGUBWF
# A selection has been stored as ZLMADAEVUHVGXWMEPNWL
# A selection has been stored as KHFLFTMMJNNIDWFWNLPS
# A selection has been stored as RISURBMJDCLDDGDBZNWS
# A selection has been stored as YNYHJDPOVSMLEYWPKUVT
# A selection has been stored as PYYSDEVGQYQTDKKVPAUL
# A selection has been stored as LCPPFKXGVBZKUCVFYYIB
# A selection has been stored as ZZKQGGFAWDUJBEISXSYO
# A selection has been stored as PEKSYTFTDXDTJSNZLCLW
# A selection has been stored as QODRWQXYFDVELWXIXXLT
# A selection has been stored as WSWXJGQRWFBQUWKIGDBL
# A selection has been stored as PPTTDYXDPXLHTWQZMYEI
# A selection has been stored as OCYDXKYAYDMNVSSWUULP
# A selection has been stored as NGEFLKITRJSNPJEPNDOH
# A selection has been stored as TGIFAWKLGWSFHSDDVELG
# A selection has been stored as QJHYIYZTFOLGLUZKUZTN
# A selection has been stored as FXPKTBADNKMUPHDHSGJS
# A selection has been stored as XZBGBONILJFSPXJEYQUB
# A selection has been stored as ZZWLZOWLPQNLNKKMZXEX
# A selection has been stored as CYUNYKZHVYMERXTZQQPK
# A selection has been stored as TVIVWKOGXPUNRXTHVCPK
# A selection has been stored as XFMHFYJUYHPSTEZTHROK
# A selection has been stored as NHGXTXQDDAOKPZNEOBDZ
# A selection has been stored as ZXHTYXGHEIDCRUVFUUJG
# A selection has been stored as GHXUFQYJHAWXAOXTZMBD
# A selection has been stored as KVZQACVDBKIQAEOLTCKN
# Average RMS from step 0 to step 1 is 0.049
# Length of RMS 1
# Plotting at step 0
# Finished step 0
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_1.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_1.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_1.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:51      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_1.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_2.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_2.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_2.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_2.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_2.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_2.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:53      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_2.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_3.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_3.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_3.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_3.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_3.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_3.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:53      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_3.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_4.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_4.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_4.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_4.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_4.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_4.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:53      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_4.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_5.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_5.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_5.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_5.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_5.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_5.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:53      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_5.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_6.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_6.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_6.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_6.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_6.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_6.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:53      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_6.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_7.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_7.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_7.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_7.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_7.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_7.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:53      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_7.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_8.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_8.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_8.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_8.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_8.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_8.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:54      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_8.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_9.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_9.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_9.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_9.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_9.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_9.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:54      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_9.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_10.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_10.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_10.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_10.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_10.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_10.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:54      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_10.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_11.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_11.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_11.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_11.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_11.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_11.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:55      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_11.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_12.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_12.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_12.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_12.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_12.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_12.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:55      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_12.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_13.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_13.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_13.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_13.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_13.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_13.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:55      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_13.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_14.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_14.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_14.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_14.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_14.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_14.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:55      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_14.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_15.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_15.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_15.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_15.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_15.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_15.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:55      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_15.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_16.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_16.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_16.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_16.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_16.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_16.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:56      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_16.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_17.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_17.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_17.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_17.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_17.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_17.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:56      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_17.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_18.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_18.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_18.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_18.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_18.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_18.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:56      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_18.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_19.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_19.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_19.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_19.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_19.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_19.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:15:57      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_19.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_20.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_20.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_20.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ...
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_1434.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:20: 5      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_1434.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_1435.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_1435.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_1435.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_1435.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_1435.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_1435.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:20: 5      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_1435.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_1436.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_1436.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_1436.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_1436.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_1436.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_1436.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:20: 5      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_1436.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_1437.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_1437.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_1437.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_1437.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_1437.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_1437.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:20: 5      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_1437.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_1438.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_1438.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_1438.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_1438.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_1438.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_1438.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:20: 6      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_1438.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_1439.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_1439.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_1439.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_1439.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_1439.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_1439.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:20: 6      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_1439.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_1440.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_1440.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_1440.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
#
# ******************************************************************************
# *          TReK (Trajectory REfinement & Kinematics) version 2.10            *
# * Reference : S.Fischer & M.Karplus, Chem. Phys. Letters vol.194, p.252, 1992*
# ******************************************************************************
#  SELRPN>      5 atoms have been selected out of     22
#
#  TReK initialized with MAXPoints =            32
#  If there is a heap failure, reduce MAXPoints.
#
#    TReK>            traj read name vacuum/dcd_evolve/evolve_1440.dcd begin 1 skip 1
#  VOPEN> Attempting to open::VACUUM/DCD_EVOLVE/EVOLVE_1440.DCD::
#  OPNLGU> Unit 40 opened for READONLY access to VACUUM/DCD_EVOLVE/EVOLVE_1440.DCD
#
#  READING TRAJECTORY FROM UNIT  40
#    NUMBER OF COORDINATE SETS IN FILE:          32
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:           32
#
#  TITLE>  * EXECUTING CHARMM SCRIPT FROM PYTHON
#  TITLE>  *  DATE:     1/13/23     18:20: 6      CREATED BY USER: brookscl
#  TITLE>  *
#
#  The first coordinate-set will be used as
#  reference-set for coordinate orientation.
#  - Its orientation will NOT be changed.
#  - It will ALSO be used as the 1st path-point.
#
#    32 CORD RECORDS READ FROM   1 UNITS STARTING WITH UNIT  40
#  RUNNING FROM STEP       1 TO       32 SKIPPING    1 STEPS BETWEEN RECORDS
#  Time step was  2.0454830E-02 AKMA time units.
#  VCLOSE: Closing unit   40 with status "KEEP"
#
# Number of starting Path-Points: NPOINT =           32
#
#    TReK>            !traj read name vacuum/dcd_evolve/refine_1440.dcd begin 1 skip 1
#
#    TReK>            fp trnc 24
#
#    TReK>            !wrkp trnc 24 bead 32 grid 64 rtyp 1 rfrc 10.0 step 0.00125
#
#    TReK>            traj write name vacuum/dcd_evolve/refine_1441.dcd restart cpr/diala.cpr
#  VOPEN> Attempting to open::vacuum/dcd_evolve/refine_1441.dcd::
#  OPNLGU> Unit 40 opened for WRITE access to vacuum/dcd_evolve/refine_1441.dcd
#
#      32   COORDINATE SETS STARTING FROM
#      STEP NO        1   FOR EVERY     1  STEPS
#      WRITTEN ON UNIT   40
#
#  VCLOSE: Closing unit   40 with status "KEEP"
#  VOPEN> Attempting to open::cpr/diala.cpr::
#  OPNLGU> Unit 40 opened for WRITE access to cpr/diala.cpr
#  VCLOSE: Closing unit   40 with status "KEEP"
#
#    TReK>            quit
# [output:0]
# [output:0]
# [output:0]
# [output:0]
# [output:0]
# [output:0]
# Received Keyboard Interrupt. Sending signal SIGINT to engines...
# Stopping controller
# Stopping cluster <Cluster(cluster_id='1673651724-95sw', profile='default', controller=<running>, engine_sets=['1673651725'])>
# Controller stopped: {'exit_code': 0, 'pid': 7988, 'identifier': 'ipcontroller-1673651724-95sw-7981'}
# Stopping engine(s): 1673651725

# %% [markdown]
# # Summary
# ## Do you see how the minimum energy path through the $\phi,\psi$ landscape moves through successive iterations of the string to follow the energy surface?
# ## This example should serve as a jumping off point for building other examples of MPI parallel applications using mpi4py and pyCHARMM
