# %% [markdown]
# # Replica Exchange Simulation to Compute Protonation Free Energy of a Lys Residue in Vacuum
# <div class="alert alert-block alert-info">
#     <b>Note:</b> This notebook uses ipyparallel and mpi4py for parallel distribution of string beads. It takes less than 20 minutes to complete running interactively on an 8-core Intel 2.3 GHz processor MacBookPro using 8 parallel tasks and the parameters specified below.</div>

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### In this tutorial, we are going to use Hamiltonian replica exchange simulation to compute protonation free energy of a Lys residue in vacuum.
#
# ### Below is the Lys residue we are going to simulate. $CH_{3}CO-$ and $CH_{3}NH-$ groups are patched at the N- and C-termini, respectively. We set up a hybrid system here, where both $\color{blue}{\text {protonated state (state 1)}}$ and $\color{red}{\text{unprotonated state (state 2)}}$ are present. Potential energy of the system is as follows:
#
# $$
# U=U_{x_0,x_0}+\lambda (U_{x_1,x_1}+U_{x_0,x_1})+(1-\lambda)(U_{x_2,x_2}+U_{x_0,x_2})
# $$
#
#
#
# <img src="fig/fig2-lys.png" width=300 height=300/>
#
# ### In a replica exchange simulation, we have multiple <b>replicas</b> of the same system simulated under different <b>conditions</b>. Periodically, exchange will be attempted between neighboring replicas. To obtain correct distribution, the exchange ratio is determined accoriding to the Metropolois criterion. In this tutorial, different conditions correspond to different $\lambda$ values in the above equation.
#
#
#
# <img src="fig/fig1-rep-ex.png" width=600 height=500/>

# %% [markdown]
# ## Prerequisite

# %% [markdown]
# ### To run this tutorial, we need to compile CHARMM $\color {pink} {\text {without MPI}}$ (having ```--without-mpi``` in configure). Also, this tutorial uses python module mpi4py (for replica exchange) and FastMBAR (for free energy calculations), which can be installed using pip.

# %% [markdown]
# ## How to run this script (non-interactively)

# %% [markdown]
# ### Here we are going to run 8 replicas using 8 processes
#
# ```
# mpirun -np 8 --quiet python rep_ex_amino_acid.py 8
#
# ```

# %% [markdown]
# ## Explanation of the script

# %% [markdown]
# ### As always, load the following pyCHARMM modules at the beginning. For this tutorial, we also need mpi4py to perform replica exchange and FastMBAR for free energy calculations.
#
# ```
#
# from mpi4py import MPI
# import FastMBAR
#
# import os
# import sys
# import subprocess
# import numpy as np
# import pandas as pd
#
# import pycharmm
# import pycharmm.read as read
# import pycharmm.lingo as lingo
# import pycharmm.generate as gen
# import pycharmm.settings as settings
# import pycharmm.write as write
# import pycharmm.nbonds as nbonds
# import pycharmm.ic as ic
# import pycharmm.coor as coor
# import pycharmm.energy as energy
# import pycharmm.dynamics as dyn
# import pycharmm.minimize as minimize
# import pycharmm.crystal as crystal
# import pycharmm.select as select
# import pycharmm.image as image
# import pycharmm.psf as psf
# import pycharmm.param as param
# import pycharmm.cons_harm as cons_harm
# import pycharmm.cons_fix as cons_fix
# import pycharmm.shake as shake
# import pycharmm.scalar as scalar
# import pycharmm.charmm_file as charmm_file
# ```

# %% [markdown]
# ### We first define some variables used in our simulation, including number of $\lambda$ windows/replicas (equals number of processes in this example), simulation temperature, number of replica exchange cycles, number of steps per cycle, etc.

# %% [markdown]
# ```
# # user defined variables
# nl_chem = 8 #nl_chem=int(sys.argv[1]) # number of windows in lambda_chem
# tsim=298.15              # simulation temperature
# ncycles=1000             # number of cycles
# nsteps_per_cyc=1000      # number of steps per cycle
#
# # residue name and segment id specific to this system
# comp='lys'
# segid='PROT'
#
# # if we find that additional simulation time is needed after the first run,
# # we can restart/continue our simulation by chaning variable itt to 2
# itt=1                    # run index
# ittm1=itt-1              # index of previous run
#
# # for free energy calculation, we need to recompute energies for dcd trajectories.
# # if we saved dcd too frequently and would like to reduce the frequency in energy
# # calculations, we could increase variable skip_dcd.
# skip_dcd=1
#
# # boltzmann constant and inverse temperature
# kB=0.0019872042586408316 # kcal/mol/K
# beta=1/kB/tsim
#
#
# ```

# %% [markdown]
# ### The following script is for MPI setup. In this tutorial, the number of $\lambda$ windows is equal to the number of processes.
# ```
# # mpi setup
# comm=MPI.COMM_WORLD
# nproc=comm.Get_size()
# rank=comm.Get_rank()
# repl_id=rank
#
# ```

# %% [markdown]
# ### Set up directories for topology/parameter files, working directory, and output directory
# ```
# # directories
# param_dir='toppar'
# wrk_dir='.'
# out_dir='aa'+str(rank)
#
# ```

# %% [markdown]
# ### Speicify file names for input pdb, psf files, and output files
# ```
# # input and output files
# inp_psf_fn=wrk_dir+'/'+comp+'.psf'
# inp_pdb_fn=wrk_dir+'/'+comp+'.pdb'
# inp_box_fn=wrk_dir+'/box_size.dat'
# dcd_fn=out_dir+'/dcd/prod'+str(itt)+'.dcd'
# rst_fn=out_dir+'/res/prod'+str(itt)+'.res'
# rpr_fn=out_dir+'/res/prod'+str(ittm1)+'.res'
# pdb_fn=out_dir+'/pdb/prod'+str(itt)+'.pdb'
# log_fn=out_dir+'/out/prod'+str(itt)+'.out'
# exc_fn=out_dir+'/exc/exch'+str(itt)+'.dat'
# his_fn=out_dir+'/his/cond_his'+str(itt)+'.dat'
# cnd_fn=out_dir+'/../cond.dat'
# exch_all_fn=out_dir+'/../exchange-all-'+str(itt)+'.dat'
# exch_all_pre_fn=out_dir+'/../exchange-all-'+str(ittm1)+'.dat'
# ratio_fn=out_dir+'/../ratio-'+str(itt)+'.dat'
# ```

# %% [markdown]
# ### $\lambda$ values are linearly spaced here. We can change it to more advanced $\lambda$ schedule here if needed.
# ```
# # lambda_chem
# l_g='{0:.4f}'.format(1/(nl_chem-1)*repl_id)
#
#
# ```

# %% [markdown]
# ### File units of charmm log file, dcd file, and restart files
# ```
# # file units
# log_unit=30
# dcd_unit=40
# rst_unit=50  # unit for current restart file
# rpr_unit=70  # unit for previous restart file
# ```

# %% [markdown]
# ### Create directories for output files
#
# ```
# # create directories
# os.system('mkdir -p '+out_dir+'/dcd')
# os.system('mkdir -p '+out_dir+'/res')
# os.system('mkdir -p '+out_dir+'/pdb')
# os.system('mkdir -p '+out_dir+'/out')
# os.system('mkdir -p '+out_dir+'/exc')
# os.system('mkdir -p '+out_dir+'/his')
#
# ```

# %% [markdown]
# ### Conditions ($\lambda$ values here) used in replica exchange
# ```
# def write_cond_file():
#     ## save the conditions to a file
#     sendbuf=np.array([float(l_g)],dtype='f')
#     recvbuf=None
#     if rank==0:
#        recvbuf = np.empty([nproc, 1], dtype='f')
#     comm.Gather(sendbuf,recvbuf,root=0)
#     if rank==0:
#        np.savetxt(cnd_fn,recvbuf,fmt='%.4f')
#     comm.barrier()
#     # broadcast condition array
#     if rank==0:
#         cond_array=recvbuf
#     else:
#         cond_array=np.empty([nproc, 1], dtype='f')
#     comm.Bcast(cond_array, root=0)
#     return cond_array
#
# def get_latest_lmd(cond_arr):
#     exch_all_pre=np.loadtxt(exch_all_pre_fn,usecols=(9),dtype=int)
#     repid_new=exch_all_pre[-1*nproc:]-1
#     l='{0:.4f}'.format(cond_arr[repid_new==rank][0][0])
#     condid=np.where(repid_new==rank)[0][0]
#     #print(rank+1,intra,inter,condid)
#     return l,condid
#
#
# cond_arr=write_cond_file()
# if itt >= 2:
#        l,condid=get_latest_lmd(cond_arr)
# else:
#        condid=rank
#        l=l_g
# ```

# %% [markdown]
# ### Specify charmm output file
#
# ```
# clog=charmm_file.CharmmFile(file_name=log_fn,file_unit=log_unit,read_only=False,formatted=True)
# lingo.charmm_script('outu '+str(log_unit))
# ```

# %% [markdown]
# ### Read topology and parameter files. The topology file is special here since we have a hybrid system, contatining both protonated and unprotonated form of Lys
# ```
# read.rtf(param_dir+'/top_all36_prot_hedi_xrliu.rtf')
# read.prm(param_dir+'/par_all36m_prot.prm',flex=True)
# ```

# %% [markdown]
# ### Read psf and pdb file of the initial structure
# ```
# read.psf_card(inp_psf_fn)
# read.pdb(inp_pdb_fn,resid=True)
# ```

# %% [markdown]
# ### Set up periodic boundary condition
# ```
# size=np.loadtxt(inp_box_fn,usecols=(0))
# crystal.define_cubic(size)
# crystal.build(12)
# # shift box center to origin
# pos=coor.get_positions()
# coor.set_positions(pos-size*0.5)
# offset=0
# image.setup_segment(offset,offset,offset,segid)
# # write coordinates
# write.coor_pdb(out_dir+'/init.pdb')
#
# ```

# %% [markdown]
# ### Define substituents at a given site: here the protonated state and the unprotonated state. Then use "BLOCK" function in CHARMM to make them not interact with each other
#
# ```
#
# def define_sub(aa,ires):
#     '''
#     define substituents
#     '''
#     resn=aa.upper()
#     resid=str(ires)
#     atom_list=titr_grp(resn)
#     sele_w=~pycharmm.SelectAtoms(select_all=True)
#     sele_m=~pycharmm.SelectAtoms(select_all=True)
#     sele_p=~pycharmm.SelectAtoms(select_all=True)
#     sele_u=~pycharmm.SelectAtoms(select_all=True)
#     for name in atom_list:
#         sele_w = sele_w | pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=resid,atom_type=name+'W')
#         sele_m = sele_m | pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=resid,atom_type=name+'M')
#         sele_p = sele_p | pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=resid,atom_type=name+'P')
#         sele_u = sele_u | pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=resid,atom_type=name+'U')
#     sele_w.store('site{}{}subW'.format(resn,resid))
#     sele_m.store('site{}{}subM'.format(resn,resid))
#     sele_p.store('site{}{}subP'.format(resn,resid))
#     sele_u.store('site{}{}subU'.format(resn,resid))
#
# class set_block:
#     '''
#     set up block for simulation
#     '''
#     def __init__(self,aa='',ires='1',nstates='2',lmd=''):
#         self.resn=aa.upper()
#         self.resid=str(ires)
#         self.nstat=int(nstates)
#         self.lmd=float(lmd)
#     def run(self):
#         self.set_name()
#         self.reset()
#         self.call()
#     def set_name(self):
#         sele_name_w='site%s%ssubW'%(self.resn,self.resid)
#         sele_name_m='site%s%ssubM'%(self.resn,self.resid)
#         sele_name_p='site%s%ssubP'%(self.resn,self.resid)
#         sele_name_u='site%s%ssubU'%(self.resn,self.resid)
#         if self.resn == 'ASP' or self.resn == 'GLU':
#            self.sele_name=[sele_name_w,sele_name_m,sele_name_p]
#         elif self.resn == 'HSD':
#            self.sele_name=[sele_name_w,sele_name_u]
#         elif self.resn == 'HSE':
#            self.sele_name=[sele_name_w,sele_name_m]
#         elif self.resn == 'LYS':
#            self.sele_name=[sele_name_w,sele_name_m]
#         elif self.resn == 'HSP':
#            self.sele_name=[sele_name_w,sele_name_u,sele_name_m]
#     def reset(self):
#         lingo.charmm_script('''
#               BLOCK %s
#                     clear
#               END
#         '''%(self.nstat+1))
#     def call(self):
#         excl_list=''
#         for i in range(0,self.nstat):
#             for j in range(i+1,self.nstat):
#                 excl_list=excl_list+str(i+2)+' '+str(j+2)+' '
#         lingo.charmm_script('''
#               BLOCK {nblk}
#                     call 2 sele {sele1} end
#                     call 3 sele {sele2} end
#
#                     coef 1 1 1.0
#                     coef 1 2 {lmbd1}
#                     coef 1 3 {lmbd2}
#
#                     coef 2 2 {lmbd1}
#                     coef 2 3 0.0
#
#                     coef 3 3 {lmbd2}
#
#                     excl {excl}
#
#                     rmla bond thet impr
#                     msma
#               END
#         '''.format(nblk=self.nstat+1,
#                    sele1=self.sele_name[0],
#                    sele2=self.sele_name[1],
#                    lmbd1=self.lmd,
#                    lmbd2=1.0-self.lmd,
#                    excl=excl_list))
#
#
# define_sub(comp,ires=1)
#
# blk=set_block(comp,ires=1,nstates='2',lmd=l)
# blk.run()
# ```

# %% [markdown]
# ### Set up nonbonded interactions
#
# ```
# nbond={'elec': True,
#        'atom': True,
#        'cdie': True,
#        'fswitch': True,
#        'eps': 1,
#        'vdw': True,
#        'vatom': True,
#        'vfswitch': True,
#        'cutnb': 14,
#        'cutim': 14,
#        'ctofnb': 12,
#        'ctonnb': 10,
#        'ewald': False
#       }
# nb_nopme=pycharmm.NonBondedScript(**nbond)
# nb_nopme.run()
# ```

# %% [markdown]
# ### Restrain the conformations between the protonated form and unprotonated form
#
# ```
#
# class resd_restrain:
#     '''
#     restrain all or heavy atoms between analogous groups of the 2 or 3 protonation states using resd restraint.
#     dynamics doesn't work if analogous atoms are on top of each other.
#     '''
#     def __init__(self,aa='',ires='',heavy=True):
#         self.heavy=heavy
#         self.resn=aa.upper()
#         self.resid=str(ires)
#     def run(self):
#         self.reset()
#         self.restrain()
#         self.show()
#     def reset(self):
#         lingo.charmm_script('RESD reset')
#     def resd(self,name):
#         sel_w=pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=self.resid,atom_type=name+'W')
#         sel_m=pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=self.resid,atom_type=name+'M')
#         sel_p=pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=self.resid,atom_type=name+'P')
#         sel_u=pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=self.resid,atom_type=name+'U')
#         w=sel_w.get_n_selected()
#         m=sel_m.get_n_selected()
#         p=sel_p.get_n_selected()
#         u=sel_u.get_n_selected()
#         if w==1 and m==1:
#            lingo.charmm_script('resd kval 100 rval 0.0 eval 2 ival 1 1.0 %s %s %s %s %s %s'%
#                                (segid,self.resid,name+'W',segid,self.resid,name+'M'))
#         if w==1 and p==1:
#            lingo.charmm_script('resd kval 100 rval 0.0 eval 2 ival 1 1.0 %s %s %s %s %s %s'%
#                                (segid,self.resid,name+'W',segid,self.resid,name+'P'))
#         if w==1 and u==1:
#            lingo.charmm_script('resd kval 100 rval 0.0 eval 2 ival 1 1.0 %s %s %s %s %s %s'%
#                                (segid,self.resid,name+'W',segid,self.resid,name+'U'))
#     def restrain(self):
#         atom_list=titr_grp(self.resn)
#         for atom_name in atom_list:
#             if self.heavy==True:  # restrain heavy atoms
#                if atom_name[0]!='H':
#                   self.resd(atom_name)
#             else:                 # restrain all atoms
#                self.resd(atom_name)
#     def show(self):
#         lingo.charmm_script('print resdistances')
#         energy.show()
#
#
#
# restrain=resd_restrain(comp,ires=1)
# restrain.run()
# ```

# %% [markdown]
# ### If this the first run, do a quick energy minimization
# ```
# if itt == 1:
#     minimize.run_sd(nstep=50,nprint=10,tolenr=1e-3,tolgrd=1e-3)
#     energy.show()
#     # write coordinates
#     write.coor_pdb(out_dir+'/mini.pdb')
# ```

# %% [markdown]
# #### Set up SHAKE and fbeta before we run dynamics
# ```
# lingo.charmm_script('''
#           faster on
# ''')
# shake.on(bonh=True, fast=True, tol=1e-7)
# n = psf.get_natom()
# scalar.set_fbetas([1.0] * n)
# ```

# %% [markdown]
# ### Run replica exchange simulations
#
# ```
# dyn_dict={
#     'leap': True,
#     'verlet': False,
#     'cpt': False,
#     'new': False,
#     'langevin': True,
#     'omm': False,
#     'start': True,
#     'timestep': 0.002,
#     'nstep': nsteps_per_cyc,
#     'nsavc': 0,
#     'nsavv': 0,
#     'nsavl': 0,      # frequency for saving lambda values in lamda-dynamics
#     'nprint': nsteps_per_cyc, # Frequency to write to output
#     'iprfrq': nsteps_per_cyc, # Frequency to calculate averages
#     'isvfrq': nsteps_per_cyc, # Frequency to save restart file
#     'ntrfrq': 5000,
#     'inbfrq':-1,
#     'ihbfrq':0,
#     'ilbfrq':0,
#     'imgfrq':-1,
#     'iunrea':-1,
#     'iunwri':rst_unit,
#     'iuncrd':-1,
#     'iunldm':-1,
#     'firstt': tsim,
#     'finalt': tsim,
#     'tstruct': tsim,
#     'tbath': tsim,
#     'iasors': 1, # assign velocities
#     'iasvel': 1, # method for assignment of velocities during heating & equil when IASORS is nonzero.
#                  # This option also controls the initial assignment of velocities
#     'iscale': 0, # not scale velocities on a restart
#     'scale': 1,  # scaling factor for velocity scaling
#     'ichecw': 0, # not check temperature
#     'echeck': -1 # not check energy
# }
#
#
# ...
#
#
# rex=rep_ex(ncycle=ncycles,condid=condid,lmd=l,conditions=cond_arr)
# rex.run()
# ```

# %% [markdown]
# ### In the above replica exchange simulations, trajecotries are saved based on replica instead of condition. We need to unmix dcds here
#
# ```
# rex.trj_unmixing()
# comm.barrier()
# ```

# %% [markdown]
# ### To obtain exchange accpetance ratio, we can do
#
# ```
# rex.trj_unmixing()
# comm.barrier()
# ```

# %% [markdown]
# ### To compute free energy free energy profile as a function of $\lambda$, we need to recompute energies for the unmixed trajectory and then use MBAR
#
# ```
# def calc_ener(cond_array):
#     dcd_cond_fn='cond'+str(rank)+'/dcd/prod'+str(itt)+'.dcd'
#     os.system('mkdir -p cond'+str(rank)+'/ener')
#     for i in range(0,nproc):
#         l_new=cond_array[i][0]
#         blk=set_block(comp,ires=1,nstates='2',lmd=l_new)
#         blk.run()
#         #print(l_new)
#         ener_fn='cond'+str(rank)+'/ener/ener'+str(itt)+'-'+str(l_new)+'.dat'
#         dcd_cond=charmm_file.CharmmFile(file_name=dcd_cond_fn,file_unit=7,read_only=True,formatted=False)
#         lingo.charmm_script('traj query unit 7')
#         nf=lingo.get_energy_value('NFILE')
#         skip=lingo.get_energy_value('SKIP')
#         lingo.charmm_script('traj firstu 7 nunit 1 skip %s'%(skip*skip_dcd))
#         ener=open(ener_fn,'w',buffering=1)
#         settings.set_verbosity(0)
#         for iframe in range(0,int(nf/skip_dcd)):
#             lingo.charmm_script('''
#                        traj read
#                        energy
#             ''')
#             e=lingo.get_energy_value('ENER')
#             ener.write('%7i %13.4f\n'%(iframe,e))
#         ener.close()
#         dcd_cond.close()
#
# def mbar(combine,cond_array):
#     if rank==0:
#        if combine==True:
#           excl=10
#           configs=int(itt*ncycles/skip_dcd)-excl
#           beg=1
#        else:
#           excl=10
#           configs=int(ncycles/skip_dcd)-excl
#           beg=itt
#        ener=np.zeros((nproc,configs,nproc), dtype = float)
#        for i in range(0,nproc):
#            # protein calc energies loaded in steps
#            for step in range(0,nproc):
#                l_new=cond_array[step][0]
#                #fileName = "cond"+str(i)+"/ener/ener-"+str(l_new)+".dat"
#                #tmp = np.loadtxt(fileName,dtype=float,usecols=(1),skiprows=0,max_rows=configs)
#                for ii in range(beg,itt+1):
#                    fileName = "cond"+str(i)+"/ener/ener"+str(ii)+"-"+str(l_new)+".dat"
#                    tmpi = np.loadtxt(fileName,dtype=float,usecols=(1),skiprows=0,max_rows=ncycles)
#                    if ii>beg:
#                       tmp=np.concatenate((tmp,tmpi))
#                    elif ii==beg:
#                       tmp=tmpi
#                if step > 0:
#                    tmp2 = np.column_stack((tmp2,tmp))
#                else:
#                    tmp2=np.copy(tmp)
#            ener[i,:,:] = tmp2[excl:,:]
#
#        # calculate free energy difference using FastMBAR
#        N_k = [configs for i in range(nproc)]
#        N_k = np.asarray(N_k)
#        tmp = ener.reshape((-1,nproc))
#        u_kn = tmp.T * beta
#        print(u_kn)
#        print(N_k)
#        mb = FastMBAR.FastMBAR(energy = u_kn, num_conf = N_k, cuda = False, bootstrap=True, verbose=True)
#        F = mb.F
#        F_std = mb.F_std
#        print("F is:",F)
#        print("F_std is:",F_std)
#
#        # write to disk
#        fp=open('mbar.out','w')
#        for i in range(len(F)):
#            # convert reduced energies back to regular energies
#            fp.write("%.6f %.6f\n" % (F[i]/beta,F_std[i]/beta))
#        fp.close()
#
#
#
# calc_ener(cond_arr)
# comm.barrier()
# mbar(combine=True,cond_array=cond_arr)
# comm.barrier()
# lingo.charmm_script('stop')
#
#
# ```

# %% [markdown]
# # However, we can also run this interactively in the jupyter notebook for a small enough example using ipcluster.
# ## Set-up mpi engines for parallel run of 8 processes:

# %%
import ipyparallel as ipp
# Set up ipcluster MPI engines for n tasks
cluster = ipp.Cluster(engines="MPI",n=8)
cluster.start_and_connect_sync()
# Out:
# Starting 8 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/8 [00:00<?, ?engine/s]

# %% [markdown]
# # Replica exchange script discussed above.
# <div class="alert alert-block alert-info">
#     <b>Note:</b> We use ipyparallel "magics" (<i>%%px</i>) to enable parallel execution of the cell blocks</div>

# %%
# %%px
# '''
# Hamiltonian replica exchange simulation of 2-state amino acid in vacuum.
# Only perform exchange in lambda_chem space.
# Run NVT simulations using CPU (w/o PME, since "BLOCK not implemented for COLFFT" in CPU).
# '''
#
# from mpi4py import MPI
# import FastMBAR
#
# import os
# import sys
# import subprocess
# import numpy as np
# import pandas as pd
#
# import pycharmm
# import pycharmm.read as read
# import pycharmm.lingo as lingo
# import pycharmm.generate as gen
# import pycharmm.settings as settings
# import pycharmm.write as write
# import pycharmm.nbonds as nbonds
# import pycharmm.ic as ic
# import pycharmm.coor as coor
# import pycharmm.energy as energy
# import pycharmm.dynamics as dyn
# import pycharmm.minimize as minimize
# import pycharmm.crystal as crystal
# import pycharmm.select as select
# import pycharmm.image as image
# import pycharmm.psf as psf
# import pycharmm.param as param
# import pycharmm.cons_harm as cons_harm
# import pycharmm.cons_fix as cons_fix
# import pycharmm.shake as shake
# import pycharmm.scalar as scalar
# import pycharmm.charmm_file as charmm_file
#
# # user defined variables
# nl_chem = 8 # nl_chem=int(sys.argv[1]) # number of windows in lambda_chem
# tsim=298.15              # simulation temperature
# ncycles=1000             # number of cycles
# nsteps_per_cyc=1000      # number of steps per cycle
#
# # residue name and segment id specific to this system
# comp='lys'
# segid='PROT'
#
# # if we find that additional simulation time is needed after the first run,
# # we can restart/continue our simulation by chaning variable itt to 2
# itt=1                    # run index
# ittm1=itt-1              # index of previous run
#
# # for free energy calculation, we need to recompute energies for dcd trajectories.
# # if we saved dcd too frequently and would like to reduce the frequency in energy
# # calculations, we could increase variable skip_dcd.
# skip_dcd=1
#
# # boltzmann constant and inverse temperature
# kB=0.0019872042586408316 # kcal/mol/K
# beta=1/kB/tsim
#
# ###################################
# # mpi
# comm=MPI.COMM_WORLD
# nproc=comm.Get_size()
# rank=comm.Get_rank()
# repl_id=rank
#
# ###################################
# # directories
# param_dir='toppar'
# wrk_dir='.'
# out_dir='aa'+str(rank)
#
# ###################################
# # input and output files
# inp_psf_fn=wrk_dir+'/'+comp+'.psf'
# inp_pdb_fn=wrk_dir+'/'+comp+'.pdb'
# inp_box_fn=wrk_dir+'/box_size.dat'
# dcd_fn=out_dir+'/dcd/prod'+str(itt)+'.dcd'
# rst_fn=out_dir+'/res/prod'+str(itt)+'.res'
# rpr_fn=out_dir+'/res/prod'+str(ittm1)+'.res'
# pdb_fn=out_dir+'/pdb/prod'+str(itt)+'.pdb'
# log_fn=out_dir+'/out/prod'+str(itt)+'.out'
# exc_fn=out_dir+'/exc/exch'+str(itt)+'.dat'
# his_fn=out_dir+'/his/cond_his'+str(itt)+'.dat'
# cnd_fn=out_dir+'/../cond.dat'
# exch_all_fn=out_dir+'/../exchange-all-'+str(itt)+'.dat'
# exch_all_pre_fn=out_dir+'/../exchange-all-'+str(ittm1)+'.dat'
# ratio_fn=out_dir+'/../ratio-'+str(itt)+'.dat'
# fe_fn=out_dir+'/../mbar.out'
#
#
# # lambda_chem
# l_g='{0:.4f}'.format(1/(nl_chem-1)*repl_id)
#
# # file units
# log_unit=30
# dcd_unit=40
# rst_unit=50
# rpr_unit=70  # unit previous restart file
#
# # create directories
# os.system('mkdir -p '+out_dir+'/dcd')
# os.system('mkdir -p '+out_dir+'/res')
# os.system('mkdir -p '+out_dir+'/pdb')
# os.system('mkdir -p '+out_dir+'/out')
# os.system('mkdir -p '+out_dir+'/exc')
# os.system('mkdir -p '+out_dir+'/his')
#
# def open_clog():
#     '''
#     specify charmm output file for a given system
#     '''
#     clog=charmm_file.CharmmFile(file_name=log_fn,file_unit=log_unit,read_only=False,formatted=True)
#     lingo.charmm_script('outu '+str(log_unit))
#     return clog
#
# def close_clog(clog):
#     lingo.charmm_script('outu 6')
#     clog.close()
#
# def read_param():
#     read.rtf(param_dir+'/top_all36_prot_hedi_xrliu.rtf')
#     read.prm(param_dir+'/par_all36m_prot.prm',flex=True)
#
# def read_init():
#     read.psf_card(inp_psf_fn)
#     read.pdb(inp_pdb_fn,resid=True)
#
# def titr_grp(resn):
#     '''
#     atom names in the titratable group for a given amino acid
#     '''
#     if resn == 'ASP':
#        type_list=['CB','HB1','HB2','CG','OD1','OD2','HD1','HD2']
#     elif resn == 'GLU':
#        type_list=['CG','HG1','HG2','CD','OE1','OE2','HE1','HE2']
#     elif resn == 'HSP' or resn == 'HSD' or resn == 'HSE':
#        type_list=['CB','HB1','HB2','CG','ND1','HD1','CE1','HE1','CD2','HD2','NE2','HE2']
#     elif resn == 'LYS':
#        type_list=['CE','HE1','HE2','NZ','HZ1','HZ2','HZ3']
#     return type_list
#
# def define_sub(aa,ires):
#     '''
#     define substituents
#     '''
#     resn=aa.upper()
#     resid=str(ires)
#     atom_list=titr_grp(resn)
#     sele_w=~pycharmm.SelectAtoms(select_all=True)
#     sele_m=~pycharmm.SelectAtoms(select_all=True)
#     sele_p=~pycharmm.SelectAtoms(select_all=True)
#     sele_u=~pycharmm.SelectAtoms(select_all=True)
#     for name in atom_list:
#         sele_w = sele_w | pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=resid,atom_type=name+'W')
#         sele_m = sele_m | pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=resid,atom_type=name+'M')
#         sele_p = sele_p | pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=resid,atom_type=name+'P')
#         sele_u = sele_u | pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=resid,atom_type=name+'U')
#     sele_w.store('site{}{}subW'.format(resn,resid))
#     sele_m.store('site{}{}subM'.format(resn,resid))
#     sele_p.store('site{}{}subP'.format(resn,resid))
#     sele_u.store('site{}{}subU'.format(resn,resid))
#
# class set_block:
#     '''
#     set up block for simulation
#     '''
#     def __init__(self,aa='',ires='1',nstates='2',lmd=''):
#         self.resn=aa.upper()
#         self.resid=str(ires)
#         self.nstat=int(nstates)
#         self.lmd=float(lmd)
#     def run(self):
#         self.set_name()
#         self.reset()
#         self.call()
#     def set_name(self):
#         sele_name_w='site%s%ssubW'%(self.resn,self.resid)
#         sele_name_m='site%s%ssubM'%(self.resn,self.resid)
#         sele_name_p='site%s%ssubP'%(self.resn,self.resid)
#         sele_name_u='site%s%ssubU'%(self.resn,self.resid)
#         if self.resn == 'ASP' or self.resn == 'GLU':
#            self.sele_name=[sele_name_w,sele_name_m,sele_name_p]
#         elif self.resn == 'HSD':
#            self.sele_name=[sele_name_w,sele_name_u]
#         elif self.resn == 'HSE':
#            self.sele_name=[sele_name_w,sele_name_m]
#         elif self.resn == 'LYS':
#            self.sele_name=[sele_name_w,sele_name_m]
#         elif self.resn == 'HSP':
#            self.sele_name=[sele_name_w,sele_name_u,sele_name_m]
#     def reset(self):
#         lingo.charmm_script('''
#               BLOCK %s
#                     clear
#               END
#         '''%(self.nstat+1))
#     def call(self):
#         excl_list=''
#         for i in range(0,self.nstat):
#             for j in range(i+1,self.nstat):
#                 excl_list=excl_list+str(i+2)+' '+str(j+2)+' '
#         lingo.charmm_script('''
#               BLOCK {nblk}
#                     call 2 sele {sele1} end
#                     call 3 sele {sele2} end
#
#                     coef 1 1 1.0
#                     coef 1 2 {lmbd1}
#                     coef 1 3 {lmbd2}
#
#                     coef 2 2 {lmbd1}
#                     coef 2 3 0.0
#
#                     coef 3 3 {lmbd2}
#
#                     excl {excl}
#
#                     rmla bond thet impr
#                     msma
#               END
#         '''.format(nblk=self.nstat+1,
#                    sele1=self.sele_name[0],
#                    sele2=self.sele_name[1],
#                    lmbd1=self.lmd,
#                    lmbd2=1.0-self.lmd,
#                    excl=excl_list))
#
# nbond={'elec': True,
#        'atom': True,
#        'cdie': True,
#        'fswitch': True,
#        'eps': 1,
#        'vdw': True,
#        'vatom': True,
#        'vfswitch': True,
#        'cutnb': 14,
#        'cutim': 14,
#        'ctofnb': 12,
#        'ctonnb': 10,
#        'ewald': False
#       }
#
# def setup_nb(nb):
#     nb_nopme=pycharmm.NonBondedScript(**nb)
#     nb_nopme.run()
#     energy.show()
#
# def set_pbc():
#     size=np.loadtxt(inp_box_fn,usecols=(0))
#     crystal.define_cubic(size)
#     crystal.build(12)
#     # shift box center to origin
#     pos=coor.get_positions()
#     coor.set_positions(pos-size*0.5)
#     offset=0
#     image.setup_segment(offset,offset,offset,segid)
#     # write coordinates
#     write.coor_pdb(out_dir+'/init.pdb')
#
# class resd_restrain:
#     '''
#     restrain all or heavy atoms between analogous groups of the 2 or 3 protonation states using resd restraint.
#     dynamics doesn't work if analogous atoms are on top of each other.
#     '''
#     def __init__(self,aa='',ires='',heavy=True):
#         self.heavy=heavy
#         self.resn=aa.upper()
#         self.resid=str(ires)
#     def run(self):
#         self.reset()
#         self.restrain()
#         self.show()
#     def reset(self):
#         lingo.charmm_script('RESD reset')
#     def resd(self,name):
#         sel_w=pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=self.resid,atom_type=name+'W')
#         sel_m=pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=self.resid,atom_type=name+'M')
#         sel_p=pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=self.resid,atom_type=name+'P')
#         sel_u=pycharmm.SelectAtoms().by_res_and_type(seg_id=segid,res_id=self.resid,atom_type=name+'U')
#         w=sel_w.get_n_selected()
#         m=sel_m.get_n_selected()
#         p=sel_p.get_n_selected()
#         u=sel_u.get_n_selected()
#         if w==1 and m==1:
#            lingo.charmm_script('resd kval 100 rval 0.0 eval 2 ival 1 1.0 %s %s %s %s %s %s'%
#                                (segid,self.resid,name+'W',segid,self.resid,name+'M'))
#         if w==1 and p==1:
#            lingo.charmm_script('resd kval 100 rval 0.0 eval 2 ival 1 1.0 %s %s %s %s %s %s'%
#                                (segid,self.resid,name+'W',segid,self.resid,name+'P'))
#         if w==1 and u==1:
#            lingo.charmm_script('resd kval 100 rval 0.0 eval 2 ival 1 1.0 %s %s %s %s %s %s'%
#                                (segid,self.resid,name+'W',segid,self.resid,name+'U'))
#     def restrain(self):
#         atom_list=titr_grp(self.resn)
#         for atom_name in atom_list:
#             if self.heavy==True:  # restrain heavy atoms
#                if atom_name[0]!='H':
#                   self.resd(atom_name)
#             else:                 # restrain all atoms
#                self.resd(atom_name)
#     def show(self):
#         lingo.charmm_script('print resdistances')
#         #energy.show()
#         lingo.charmm_script('energy omm')
#
# def mini():
#     minimize.run_sd(nstep=50,nprint=10,tolenr=1e-3,tolgrd=1e-3)
#     energy.show()
#     # write coordinates
#     write.coor_pdb(out_dir+'/mini.pdb')
#
# def dyn_init():
#     lingo.charmm_script('''
#           faster on
#     ''')
#     shake.on(bonh=True, fast=True, tol=1e-7)
#     n = psf.get_natom()
#     scalar.set_fbetas([1.0] * n)
#
#
# # CPT simulation using omm
# dyn_dict={
#     'leap': True,
#     'verlet': False,
#     'cpt': False,
#     'new': False,
#     'langevin': True,
#     'omm': False,
#     'start': True,
#     'timestep': 0.002,
#     'nstep': nsteps_per_cyc,
#     'nsavc': 0,
#     'nsavv': 0,
#     'nsavl': 0,      # frequency for saving lambda values in lamda-dynamics
#     'nprint': nsteps_per_cyc, # Frequency to write to output
#     'iprfrq': nsteps_per_cyc, # Frequency to calculate averages
#     'isvfrq': nsteps_per_cyc, # Frequency to save restart file
#     'ntrfrq': 5000,
#     'inbfrq':-1,
#     'ihbfrq':0,
#     'ilbfrq':0,
#     'imgfrq':-1,
#     'iunrea':-1,
#     'iunwri':rst_unit,
#     'iuncrd':-1,
#     'iunldm':-1,
#     'firstt': tsim,
#     'finalt': tsim,
#     'tstruct': tsim,
#     'tbath': tsim,
#     'iasors': 1, # assign velocities
#     'iasvel': 1, # method for assignment of velocities during heating & equil when IASORS is nonzero.
#                  # This option also controls the initial assignment of velocities
#     'iscale': 0, # not scale velocities on a restart
#     'scale': 1,  # scaling factor for velocity scaling
#     'ichecw': 0, # not check temperature
#     'echeck': -1 # not check energy
# }
#
#
# def nvt(run):
#     rst=charmm_file.CharmmFile(file_name=rst_fn,file_unit=rst_unit,read_only=False,formatted='formatted')
#
#     if itt>=2:
#        if run==0:
#           dyn_dict['start']=False
#           dyn_dict['restart']=True
#           dyn_dict['iunrea']=rpr_unit
#           rpr=charmm_file.CharmmFile(file_name=rpr_fn,file_unit=rpr_unit,read_only=True,formatted='formatted')
#        else:
#           dyn_dict['start']=True
#           dyn_dict['restart']=False
#           dyn_dict['iunrea']=-1
#
#     npt_prod=pycharmm.DynamicsScript(**dyn_dict)
#     npt_prod.run()
#     rst.close()
#     if itt>=2 and run==0:
#        rpr.close()
#
#     # last snapshot
#     write.coor_pdb(pdb_fn)
#
# def write_cond_file():
#     sendbuf=np.array([float(l_g)],dtype='f')
#     recvbuf=None
#     if rank==0:
#        recvbuf = np.empty([nproc, 1], dtype='f')
#     comm.Gather(sendbuf,recvbuf,root=0)
#     if rank==0:
#        np.savetxt(cnd_fn,recvbuf,fmt='%.4f')
#     comm.barrier()
#     # broadcast condition array
#     if rank==0:
#         cond_array=recvbuf
#     else:
#         cond_array=np.empty([nproc, 1], dtype='f')
#     comm.Bcast(cond_array, root=0)
#     return cond_array
#
# def get_neighbor(current_cond_id,run_id):
#     if run_id%2==0:
#        if current_cond_id%2==0:
#           neighbor_cond_id=current_cond_id+1
#        else:
#           neighbor_cond_id=current_cond_id-1
#     else:
#        if current_cond_id%2==0:
#           neighbor_cond_id=current_cond_id-1
#        else:
#           neighbor_cond_id=current_cond_id+1
#     if neighbor_cond_id<0:
#        neighbor_cond_id=0
#     if neighbor_cond_id>=nproc:
#        neighbor_cond_id=nproc-1
#     return neighbor_cond_id
#
# class rep_ex:
#       '''
#       perform Hamiltonian replica exchange (lambda_chem only)
#       '''
#       def __init__(self,ncycle='',condid='',lmd='',conditions=''):
#           self.cond_id=int(condid)
#           self.cond_array=conditions
#           self.lmd=float(lmd)
#           self.nrun=int(ncycle)
#       def run(self):
#           self.open_files()
#           for i in range(0,self.nrun):
#               #print("run {}, rank {} lambdas are intra {} and inter {}".format(i,rank,self.intra,self.inter))
#               nvt(i)
#               self.write_trj(i)
#               self.cond_data=self.gather_condid(i)
#               self.lmd_new=self.swap_neighbor(i)
#               #print("after exchange, rank {} lambdas are l {} ".format(rank,self.lmd_new))
#               self.get_ener_new()
#               self.metropolis()
#               #print('run ',i, 'cond ',self.cond_id,'Accept',self.Accept)
#               self.write_exch_all(i)
#               self.update_cond()
#           self.close_files()
#       def open_files(self):
#           # all exchange information
#           if rank==0:
#              self.exch_all=open(exch_all_fn,'w',buffering=1)
#              self.exch_all.write('# replica temp. ener. neighbor ntemp nene prob p success? newrep\n')
#           # exchange information for each replica
#           self.exch=open(exc_fn,'w',buffering=1)
#           self.exch.write('#run repl_id ener_im neighbor_repl_id ener_in prob rand accept replica_next\n')
#           # condition history for each replica
#           self.hist=open(his_fn,'w',buffering=1)
#           # dcd for each replica
#           self.dcd=charmm_file.CharmmFile(file_name=dcd_fn,file_unit=dcd_unit,read_only=False,formatted=False)
#           lingo.charmm_script('''
#           traj IWRITE {} NWRITE 1 NFILE {}
#           * title
#           *
#           '''.format(dcd_unit,self.nrun))
#       def close_files(self):
#           if rank==0:
#              self.exch_all.close()
#           self.exch.close()
#           self.hist.close()
#           self.dcd.close()
#           comm.barrier()
#       def write_trj(self,run):
#           lingo.charmm_script('traj write')
#           self.ener_im=lingo.get_energy_value('ENER')
#           self.exch.write('%5d %2d %15f '%(run,repl_id,self.ener_im))
#           self.hist.write('%i %s \n'%(run,self.lmd))
#           comm.barrier()
#       def gather_condid(self,run):
#           data=self.cond_id
#           data=comm.gather(data,root=0)
#           data=comm.bcast(data,root=0)
#           #print('run',run,'rank',rank,data)
#           return data
#       def swap_neighbor(self,run):
#           self.new_cond_id=get_neighbor(self.cond_id,run)
#           self.neighbor_repl_id=self.cond_data.index(self.new_cond_id)
#           lmd=self.cond_array[self.new_cond_id][0]
#           return lmd
#       def get_ener_new(self):
#           blk=set_block(comp,ires='1',nstates='2',lmd=self.lmd_new)
#           blk.run()
#           energy.show()
#           self.ener_in=lingo.get_energy_value('ENER')
#           self.exch.write('%2d %15f '%(self.neighbor_repl_id,self.ener_in))
#           comm.barrier()
#       def metropolis(self):
#           self.Accept=True
#           self.prob=1
#           self.rand=0
#           if self.cond_id > self.new_cond_id:
#              comm.send(self.ener_im, dest=self.neighbor_repl_id, tag=11)
#              comm.send(self.ener_in, dest=self.neighbor_repl_id, tag=12)
#           elif self.cond_id < self.new_cond_id:
#              ener_jn=comm.recv(source=self.neighbor_repl_id,tag=11)
#              ener_jm=comm.recv(source=self.neighbor_repl_id,tag=12)
#              delta=-1*beta*(ener_jm+self.ener_in-self.ener_im-ener_jn)
#              #print("beta:",beta,"delta:",delta,"ener_jm:",ener_jm,"ener_in:",self.ener_in,"ener_im:",self.ener_im,"ener_jn:",ener_jn)
#              if delta<0:
#                 self.prob=np.exp(delta)
#                 #print('prob ',self.prob)
#                 self.rand=np.random.uniform(low=0.0, high=1.0)
#                 if self.prob < self.rand:
#                    self.Accept=False
#                    #print('reject')
#           comm.barrier()
#           if self.cond_id < self.new_cond_id:
#              comm.send(self.Accept,dest=self.neighbor_repl_id,tag=13)
#           elif self.cond_id > self.new_cond_id:
#              self.Accept=comm.recv(source=self.neighbor_repl_id,tag=13)
#           comm.barrier()
#           self.exch.write('%5f %5f %5s '%(self.prob,self.rand,str(self.Accept)[0]))
#       def write_exch_all(self,run):
#           # exchange file for each replica
#           if self.Accept == True:
#              replica_next=self.neighbor_repl_id
#           else:
#              replica_next=repl_id
#           self.exch.write('%2d \n'%(replica_next))
#           exch_str='{:2d} {:12.6f} {:15.6f} {:2d} {:12.6f} {:15.6f} {:5.3f} {:5.3f} {:1s} {:2d}\n'.format(repl_id,self.cond_id,self.ener_im,self.neighbor_repl_id,self.new_cond_id,self.ener_in,self.prob,self.rand,str(self.Accept)[0],replica_next)
#           # gather all exchange info (a string) to an array
#           comm.barrier()
#           exch_str_all=comm.gather(exch_str,root=0)
#           comm.barrier()
#           if rank==0:
#              exch_list_all=[]
#              for i in range(0,nproc):
#                  exch_list_all.append(exch_str_all[i].split())
#              exch_all_array=np.array(exch_list_all)
#              exch_array_sort=pd.DataFrame(exch_all_array,columns=['repl_id','condid_m','ener_im','neighbor_repl_id','condid_n','ener_in','prob','rand','accept','neighbor_repl_id']).astype({'condid_m':float}).sort_values(by='condid_m',ascending=True).to_numpy()
#              self.exch_all.write('# Exchange %15d: STEP %12d: REPEAT     1\n'%(run+1,run+1))
#              for i in range(0,nproc):
#                  self.exch_all.write('%2d %12f %15f %2d %12f %15f %5.3f %5.3f %1s %2d\n'%
#                  (int(exch_array_sort[i,0])+1,float(exch_array_sort[i,1]),float(exch_array_sort[i,2]),
#                   int(exch_array_sort[i,3])+1,float(exch_array_sort[i,4]),float(exch_array_sort[i,5]),
#                   float(exch_array_sort[i,6]),float(exch_array_sort[i,7]),exch_array_sort[i,8],int(exch_array_sort[i,9])+1))
#       def update_cond(self):
#           # update condition
#           if self.Accept == False:
#              self.new_cond_id=self.cond_id
#              self.lmd=self.cond_array[self.new_cond_id][0]
#              blk=set_block(comp,ires='1',nstates='2',lmd=self.lmd)
#              blk.run()
#           else:
#              self.lmd=self.lmd_new
#           self.cond_id=self.new_cond_id
#       def trj_unmixing(self):
#           if rank==0:
#              #lingo.charmm_script('prnlev 10')
#              exch_all=charmm_file.CharmmFile(file_name=exch_all_fn,read_only=True,formatted=True)
#              for i in range(0,nproc):
#                  unit_inp=7+i
#                  unit_out=48+i
#                  fn_inp='aa'+str(i)+'/dcd/prod'+str(itt)+'.dcd'
#                  os.system('mkdir -p cond'+str(i)+'/dcd')
#                  fn_out='cond'+str(i)+'/dcd/prod'+str(itt)+'.dcd'
#                  lingo.charmm_script('open read file unit {} name {}'.format(unit_inp,fn_inp))
#                  lingo.charmm_script('open writ file unit {} name {}'.format(unit_out,fn_out))
#              lingo.charmm_script('merge firstu 7 nunit {} outp 48 RTOTemp excu {} NEXChange {} nrpl {} nrep 1'.format(nproc,exch_all.file_unit,ncycles,nproc))
#              exch_all.close
#       def accept_ratio(self):
#           if rank==0:
#              dat=np.loadtxt(exch_all_fn,usecols=(1,4,8),dtype={'names':('i','j','accept'),'formats':(float,float,'|S1')})
#              df=pd.DataFrame(dat)
#              #print(df)
#              df_ex=df.groupby(['i','j']).size().reset_index(name='allex')
#              df_ac=df.groupby(['i','j','accept']).size().reset_index(name='success')
#              df_ac_t=df_ac[df_ac['accept']==b'T'].reset_index()
#              print(df_ex)
#              print(df_ac_t)
#              npairs=df_ex.shape[0]
#              ratio_list=[]
#              #print(npairs)
#              for i in range(0,npairs):
#                  cond_i=df_ex.loc[i,['i']][0]
#                  cond_j=df_ex.loc[i,['j']][0]
#                  if cond_i < cond_j:
#                     if np.sum((df_ac_t['i']==cond_i) & (df_ac_t['j']==cond_j))==0:
#                        #print(cond_i,cond_j,'no successful exchange')
#                        accepted=0
#                     else:
#                        accepted=df_ac_t[(df_ac_t['i']==cond_i) & (df_ac_t['j']==cond_j)]['success'].to_numpy()[0]
#                     exchanged=df_ex[(df_ex['i']==cond_i) & (df_ex['j']==cond_j)]['allex'].to_numpy()[0]
#                     ratio=accepted/exchanged
#                     #print(cond_i,cond_j,accepted,exchanged,ratio)
#                     ratio_list.append([cond_i,cond_j,accepted,exchanged,ratio])
#              ratio_array=np.array(ratio_list)
#              #print(ratio_array)
#              np.savetxt(ratio_fn,ratio_array,fmt='%.6f')
#
# def get_latest_lmd(cond_arr):
#     exch_all_pre=np.loadtxt(exch_all_pre_fn,usecols=(9),dtype=int)
#     repid_new=exch_all_pre[-1*nproc:]-1
#     l='{0:.4f}'.format(cond_arr[repid_new==rank][0][0])
#     condid=np.where(repid_new==rank)[0][0]
#     #print(rank+1,intra,inter,condid)
#     return l,condid
#
# def calc_ener(cond_array):
#     dcd_cond_fn='cond'+str(rank)+'/dcd/prod'+str(itt)+'.dcd'
#     os.system('mkdir -p cond'+str(rank)+'/ener')
#     for i in range(0,nproc):
#         l_new=cond_array[i][0]
#         blk=set_block(comp,ires=1,nstates='2',lmd=l_new)
#         blk.run()
#         #print(l_new)
#         ener_fn='cond'+str(rank)+'/ener/ener'+str(itt)+'-'+str(l_new)+'.dat'
#         dcd_cond=charmm_file.CharmmFile(file_name=dcd_cond_fn,file_unit=7,read_only=True,formatted=False)
#         lingo.charmm_script('traj query unit 7')
#         nf=lingo.get_energy_value('NFILE')
#         skip=lingo.get_energy_value('SKIP')
#         lingo.charmm_script('traj firstu 7 nunit 1 skip %s'%(skip*skip_dcd))
#         ener=open(ener_fn,'w',buffering=1)
#         settings.set_verbosity(0)
#         for iframe in range(0,int(nf/skip_dcd)):
#             lingo.charmm_script('''
#                        traj read
#                        energy
#             ''')
#             e=lingo.get_energy_value('ENER')
#             ener.write('%7i %13.4f\n'%(iframe,e))
#         ener.close()
#         dcd_cond.close()
#
# def mbar(combine,cond_array):
#     if rank==0:
#        if combine==True:
#           excl=10
#           configs=int(itt*ncycles/skip_dcd)-excl
#           beg=1
#        else:
#           excl=10
#           configs=int(ncycles/skip_dcd)-excl
#           beg=itt
#        ener=np.zeros((nproc,configs,nproc), dtype = float)
#        for i in range(0,nproc):
#            # protein calc energies loaded in steps
#            for step in range(0,nproc):
#                l_new=cond_array[step][0]
#                #fileName = "cond"+str(i)+"/ener/ener-"+str(l_new)+".dat"
#                #tmp = np.loadtxt(fileName,dtype=float,usecols=(1),skiprows=0,max_rows=configs)
#                for ii in range(beg,itt+1):
#                    fileName = "cond"+str(i)+"/ener/ener"+str(ii)+"-"+str(l_new)+".dat"
#                    tmpi = np.loadtxt(fileName,dtype=float,usecols=(1),skiprows=0,max_rows=ncycles)
#                    if ii>beg:
#                       tmp=np.concatenate((tmp,tmpi))
#                    elif ii==beg:
#                       tmp=tmpi
#                if step > 0:
#                    tmp2 = np.column_stack((tmp2,tmp))
#                else:
#                    tmp2=np.copy(tmp)
#            ener[i,:,:] = tmp2[excl:,:]
#
#        # calculate free energy difference using FastMBAR
#        N_k = [configs for i in range(nproc)]
#        N_k = np.asarray(N_k)
#        tmp = ener.reshape((-1,nproc))
#        u_kn = tmp.T * beta
#        print(u_kn)
#        print(N_k)
#        mb = FastMBAR.FastMBAR(energy = u_kn, num_conf = N_k, cuda = False, bootstrap=True, verbose=True)
#        F = mb.F
#        F_std = mb.F_std
#        print("F is:",F)
#        print("F_std is:",F_std)
#
#        # write to disk
#        fp=open(fe_fn,'w')
#        for i in range(len(F)):
#            l=cond_array[i][0]
#            # convert reduced energies back to regular energies
#            fp.write("%.6f %.6f %.6f\n" % (l,F[i]/beta,F_std[i]/beta))
#        fp.close()
#
#
#
# def main():
#     cond_arr=write_cond_file()
#     if itt >= 2:
#        l,condid=get_latest_lmd(cond_arr)
#     else:
#        condid=rank
#        l=l_g
#     charmm_log=open_clog()
#     read_param()
#     read_init()
#     set_pbc()
#     define_sub(comp,ires=1)
#     blk=set_block(comp,ires=1,nstates='2',lmd=l)
#     blk.run()
#     setup_nb(nbond)
#
#     # NOE and IC restraints don't work in omm dynamics, although it works in omm energy.
#     # b/c in energy calculation, if a term is not present in omm, charmm will be used to compute this term.
#     restrain=resd_restrain(comp,ires=1)
#     restrain.run()
#
#     if itt == 1:
#        mini()
#     dyn_init()
#     rex=rep_ex(ncycle=ncycles,condid=condid,lmd=l,conditions=cond_arr)
#     rex.run()
#     close_clog(charmm_log)
#     rex.trj_unmixing()
#     comm.barrier()
#     rex.accept_ratio()
#     calc_ener(cond_arr)
#     comm.barrier()
#     mbar(combine=True,cond_array=cond_arr)
#     comm.barrier()
#     lingo.charmm_script('stop')
#
# if __name__ == '__main__':
#    main()
# Out:
# %px:   0%|          | 0/8 [00:00<?, ?tasks/s]
# [stdout:0]  VOPEN> Attempting to open::aa0/out/prod1.out::
#
#  CHARMM>     outu 30
# A selection has been stored as SITELYS1SUBW
# A selection has been stored as SITELYS1SUBM
# A selection has been stored as SITELYS1SUBP
# A selection has been stored as SITELYS1SUBU
#
#  VCLOSE: Closing unit   30 with status "KEEP"
#  DEBUG: new_unit          90
#  VOPEN> Attempting to open::aa0/../exchange-all-1.dat::
#
#  CHARMM>     open read file unit 7 name aa0/dcd/prod1.dcd
#  VOPEN> Attempting to open::AA0/DCD/PROD1.DCD::
#  OPNLGU> Unit  7 opened for READONLY access to AA0/DCD/PROD1.DCD
#
#
#  CHARMM>     open writ file unit 48 name cond0/dcd/prod1.dcd
#  VOPEN> Attempting to open::cond0/dcd/prod1.dcd::
#  OPNLGU> Unit 48 opened for WRITE access to cond0/dcd/prod1.dcd
#
#
#  CHARMM>     open read file unit 8 name aa1/dcd/prod1.dcd
#  VOPEN> Attempting to open::AA1/DCD/PROD1.DCD::
#  OPNLGU> Unit  8 opened for READONLY access to AA1/DCD/PROD1.DCD
#
#
#  CHARMM>     open writ file unit 49 name cond1/dcd/prod1.dcd
#  VOPEN> Attempting to open::cond1/dcd/prod1.dcd::
#  OPNLGU> Unit 49 opened for WRITE access to cond1/dcd/prod1.dcd
#
#
#  CHARMM>     open read file unit 9 name aa2/dcd/prod1.dcd
#  VOPEN> Attempting to open::AA2/DCD/PROD1.DCD::
#  OPNLGU> Unit  9 opened for READONLY access to AA2/DCD/PROD1.DCD
#
#
#  CHARMM>     open writ file unit 50 name cond2/dcd/prod1.dcd
#  VOPEN> Attempting to open::cond2/dcd/prod1.dcd::
#  OPNLGU> Unit 50 opened for WRITE access to cond2/dcd/prod1.dcd
#
#
#  CHARMM>     open read file unit 10 name aa3/dcd/prod1.dcd
#  VOPEN> Attempting to open::AA3/DCD/PROD1.DCD::
#  OPNLGU> Unit 10 opened for READONLY access to AA3/DCD/PROD1.DCD
#
#
#  CHARMM>     open writ file unit 51 name cond3/dcd/prod1.dcd
#  VOPEN> Attempting to open::cond3/dcd/prod1.dcd::
#  OPNLGU> Unit 51 opened for WRITE access to cond3/dcd/prod1.dcd
#
#
#  CHARMM>     open read file unit 11 name aa4/dcd/prod1.dcd
#  VOPEN> Attempting to open::AA4/DCD/PROD1.DCD::
#  OPNLGU> Unit 11 opened for READONLY access to AA4/DCD/PROD1.DCD
#
#
#  CHARMM>     open writ file unit 52 name cond4/dcd/prod1.dcd
#  VOPEN> Attempting to open::cond4/dcd/prod1.dcd::
#  OPNLGU> Unit 52 opened for WRITE access to cond4/dcd/prod1.dcd
#
#
#  CHARMM>     open read file unit 12 name aa5/dcd/prod1.dcd
#  VOPEN> Attempting to open::AA5/DCD/PROD1.DCD::
#  OPNLGU> Unit 12 opened for READONLY access to AA5/DCD/PROD1.DCD
#
#
#  CHARMM>     open writ file unit 53 name cond5/dcd/prod1.dcd
#  VOPEN> Attempting to open::cond5/dcd/prod1.dcd::
#  OPNLGU> Unit 53 opened for WRITE access to cond5/dcd/prod1.dcd
#
#
#  CHARMM>     open read file unit 13 name aa6/dcd/prod1.dcd
#  VOPEN> Attempting to open::AA6/DCD/PROD1.DCD::
#  OPNLGU> Unit 13 opened for READONLY access to AA6/DCD/PROD1.DCD
#
#
#  CHARMM>     open writ file unit 54 name cond6/dcd/prod1.dcd
#  VOPEN> Attempting to open::cond6/dcd/prod1.dcd::
#  OPNLGU> Unit 54 opened for WRITE access to cond6/dcd/prod1.dcd
#
#
#  CHARMM>     open read file unit 14 name aa7/dcd/prod1.dcd
#  VOPEN> Attempting to open::AA7/DCD/PROD1.DCD::
#  OPNLGU> Unit 14 opened for READONLY access to AA7/DCD/PROD1.DCD
#
#
#  CHARMM>     open writ file unit 55 name cond7/dcd/prod1.dcd
#  VOPEN> Attempting to open::cond7/dcd/prod1.dcd::
#  OPNLGU> Unit 55 opened for WRITE access to cond7/dcd/prod1.dcd
#
#
#  CHARMM>     merge firstu 7 nunit 8 outp 48 RTOTemp excu 90 NEXChange 1000 nrpl 8 nrep 1
#  READ_EXCHANGE> GOT # Exchange               1: STEP            1: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               1: STEP            1: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               2: STEP            2: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               3: STEP            3: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               4: STEP            4: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               5: STEP            5: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               6: STEP            6: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               7: STEP            7: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               8: STEP            8: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange               9: STEP            9: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              10: STEP           10: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              11: STEP           11: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              12: STEP           12: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              13: STEP           13: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              14: STEP           14: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              15: STEP           15: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              16: STEP           16: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              17: STEP           17: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              18: STEP           18: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              19: STEP           19: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              20: STEP           20: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              21: STEP           21: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              22: STEP           22: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              23: STEP           23: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              24: STEP           24: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              25: STEP           25: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              26: STEP           26: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              27: STEP           27: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              28: STEP           28: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              29: STEP           29: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              30: STEP           30: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              31: STEP           31: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              32: STEP           32: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              33: STEP           33: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              34: STEP           34: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              35: STEP           35: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              36: STEP           36: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              37: STEP           37: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              38: STEP           38: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              39: STEP           39: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              40: STEP           40: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              41: STEP           41: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              42: STEP           42: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              43: STEP           43: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              44: STEP           44: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              45: STEP           45: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              46: STEP           46: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              47: STEP           47: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              48: STEP           48: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              49: STEP           49: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              50: STEP           50: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              51: STEP           51: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              52: STEP           52: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              53: STEP           53: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              54: STEP           54: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              55: STEP           55: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              56: STEP           56: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              57: STEP           57: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              58: STEP           58: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              59: STEP           59: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              60: STEP           60: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              61: STEP           61: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              62: STEP           62: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              63: STEP           63: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              64: STEP           64: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              65: STEP           65: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              66: STEP           66: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              67: STEP           67: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              68: STEP           68: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              69: STEP           69: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              70: STEP           70: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              71: STEP           71: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              72: STEP           72: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              73: STEP           73: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              74: STEP           74: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              75: STEP           75: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              76: STEP           76: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              77: STEP           77: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              78: STEP           78: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              79: STEP           79: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              80: STEP           80: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              81: STEP           81: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              82: STEP           82: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              83: STEP           83: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              84: STEP           84: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              85: STEP           85: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              86: STEP           86: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              87: STEP           87: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              88: STEP           88: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              89: STEP           89: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              90: STEP           90: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              91: STEP           91: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              92: STEP           92: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              93: STEP           93: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              94: STEP           94: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              95: STEP           95: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              96: STEP           96: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              97: STEP           97: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              98: STEP           98: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange              99: STEP           99: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             100: STEP          100: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             101: STEP          101: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             102: STEP          102: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             103: STEP          103: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             104: STEP          104: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             105: STEP          105: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             106: STEP          106: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             107: STEP          107: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             108: STEP          108: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             109: STEP          109: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             110: STEP          110: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             111: STEP          111: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             112: STEP          112: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             113: STEP          113: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             114: STEP          114: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             115: STEP          115: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             116: STEP          116: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             117: STEP          117: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             118: STEP          118: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             119: STEP          119: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             120: STEP          120: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             121: STEP          121: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             122: STEP          122: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             123: STEP          123: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             124: STEP          124: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             125: STEP          125: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             126: STEP          126: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             127: STEP          127: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             128: STEP          128: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             129: STEP          129: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             130: STEP          130: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             131: STEP          131: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             132: STEP          132: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             133: STEP          133: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             134: STEP          134: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             135: STEP          135: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             136: STEP          136: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             137: STEP          137: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             138: STEP          138: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             139: STEP          139: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             140: STEP          140: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             141: STEP          141: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             142: STEP          142: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             143: STEP          143: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             144: STEP          144: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             145: STEP          145: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             146: STEP          146: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             147: STEP          147: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             148: STEP          148: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             149: STEP          149: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             150: STEP          150: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             151: STEP          151: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             152: STEP          152: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             153: STEP          153: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             154: STEP          154: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             155: STEP          155: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             156: STEP          156: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             157: STEP          157: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             158: STEP          158: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             159: STEP          159: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             160: STEP          160: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             161: STEP          161: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             162: STEP          162: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             163: STEP          163: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             164: STEP          164: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             165: STEP          165: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             166: STEP          166: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             167: STEP          167: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             168: STEP          168: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             169: STEP          169: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             170: STEP          170: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             171: STEP          171: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             172: STEP          172: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             173: STEP          173: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             174: STEP          174: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             175: STEP          175: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             176: STEP          176: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             177: STEP          177: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             178: STEP          178: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             179: STEP          179: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             180: STEP          180: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             181: STEP          181: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             182: STEP          182: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             183: STEP          183: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             184: STEP          184: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             185: STEP          185: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             186: STEP          186: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             187: STEP          187: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             188: STEP          188: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             189: STEP          189: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             190: STEP          190: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             191: STEP          191: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             192: STEP          192: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             193: STEP          193: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             194: STEP          194: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             195: STEP          195: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             196: STEP          196: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             197: STEP          197: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             198: STEP          198: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             199: STEP          199: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             200: STEP          200: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             201: STEP          201: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             202: STEP          202: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             203: STEP          203: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             204: STEP          204: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             205: STEP          205: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             206: STEP          206: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             207: STEP          207: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             208: STEP          208: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             209: STEP          209: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             210: STEP          210: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             211: STEP          211: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             212: STEP          212: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             213: STEP          213: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             214: STEP          214: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             215: STEP          215: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             216: STEP          216: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             217: STEP          217: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             218: STEP          218: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             219: STEP          219: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             220: STEP          220: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             221: STEP          221: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             222: STEP          222: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             223: STEP          223: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             224: STEP          224: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             225: STEP          225: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             226: STEP          226: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             227: STEP          227: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             228: STEP          228: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             229: STEP          229: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             230: STEP          230: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             231: STEP          231: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             232: STEP          232: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             233: STEP          233: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             234: STEP          234: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             235: STEP          235: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             236: STEP          236: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             237: STEP          237: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             238: STEP          238: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             239: STEP          239: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             240: STEP          240: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             241: STEP          241: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             242: STEP          242: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             243: STEP          243: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             244: STEP          244: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             245: STEP          245: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             246: STEP          246: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             247: STEP          247: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             248: STEP          248: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             249: STEP          249: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             250: STEP          250: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             251: STEP          251: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             252: STEP          252: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             253: STEP          253: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             254: STEP          254: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             255: STEP          255: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             256: STEP          256: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             257: STEP          257: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             258: STEP          258: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             259: STEP          259: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             260: STEP          260: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             261: STEP          261: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             262: STEP          262: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             263: STEP          263: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             264: STEP          264: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             265: STEP          265: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             266: STEP          266: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             267: STEP          267: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             268: STEP          268: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             269: STEP          269: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             270: STEP          270: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             271: STEP          271: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             272: STEP          272: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             273: STEP          273: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             274: STEP          274: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             275: STEP          275: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             276: STEP          276: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             277: STEP          277: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             278: STEP          278: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             279: STEP          279: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             280: STEP          280: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             281: STEP          281: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             282: STEP          282: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             283: STEP          283: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             284: STEP          284: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             285: STEP          285: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             286: STEP          286: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             287: STEP          287: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             288: STEP          288: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             289: STEP          289: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             290: STEP          290: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             291: STEP          291: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             292: STEP          292: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             293: STEP          293: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             294: STEP          294: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             295: STEP          295: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             296: STEP          296: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             297: STEP          297: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             298: STEP          298: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             299: STEP          299: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             300: STEP          300: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             301: STEP          301: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             302: STEP          302: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             303: STEP          303: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             304: STEP          304: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             305: STEP          305: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             306: STEP          306: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             307: STEP          307: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             308: STEP          308: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             309: STEP          309: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             310: STEP          310: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             311: STEP          311: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             312: STEP          312: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             313: STEP          313: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             314: STEP          314: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             315: STEP          315: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             316: STEP          316: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             317: STEP          317: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             318: STEP          318: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             319: STEP          319: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             320: STEP          320: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             321: STEP          321: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             322: STEP          322: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             323: STEP          323: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             324: STEP          324: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             325: STEP          325: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             326: STEP          326: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             327: STEP          327: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             328: STEP          328: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             329: STEP          329: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             330: STEP          330: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             331: STEP          331: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             332: STEP          332: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             333: STEP          333: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             334: STEP          334: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             335: STEP          335: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             336: STEP          336: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             337: STEP          337: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             338: STEP          338: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             339: STEP          339: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             340: STEP          340: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             341: STEP          341: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             342: STEP          342: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             343: STEP          343: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             344: STEP          344: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             345: STEP          345: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             346: STEP          346: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             347: STEP          347: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             348: STEP          348: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             349: STEP          349: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             350: STEP          350: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             351: STEP          351: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             352: STEP          352: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             353: STEP          353: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             354: STEP          354: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             355: STEP          355: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             356: STEP          356: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             357: STEP          357: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             358: STEP          358: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             359: STEP          359: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             360: STEP          360: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             361: STEP          361: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             362: STEP          362: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             363: STEP          363: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             364: STEP          364: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             365: STEP          365: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             366: STEP          366: REPEAT     1
#  READ_EXCHANGE> GOT # Exchange             367: STEP          367: REPEAT     1
# ...
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# [stdout:1]  VOPEN> Attempting to open::aa1/out/prod1.out::
#
#  CHARMM>     outu 30
# A selection has been stored as SITELYS1SUBW
# A selection has been stored as SITELYS1SUBM
# A selection has been stored as SITELYS1SUBP
# A selection has been stored as SITELYS1SUBU
#
#  VCLOSE: Closing unit   30 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>                  BLOCK 3
#
#   BLOCK>                        clear
#  Block Structure has been turned off.
#
#   BLOCK>                  END
#
#  CHARMM>
#
#
#  CHARMM>
#
#  CHARMM>                  BLOCK 3
#  Block structure initialized with   3 blocks.
#  All atoms have been assigned to block 1.
#  All interaction coefficients have been set to unity.
#   Setting number of block exclusions nblock_excldPairs=0
#
#   BLOCK>                        call 2 sele siteLYS1subW end
#  SELRPN>      7 atoms have been selected out of     40
#  The selected atoms have been reassigned to block   2
#
#   BLOCK>                        call 3 sele siteLYS1subM end
#  SELRPN>      6 atoms have been selected out of     40
#  The selected atoms have been reassigned to block   3
#
#   BLOCK>
#
#   BLOCK>                        coef 1 1 1.0
#
#   BLOCK>                        coef 1 2 0.0
#
#   BLOCK>                        coef 1 3 1.0
#
#   BLOCK>
#
#   BLOCK>                        coef 2 2 0.0
#
#   BLOCK>                        coef 2 3 0.0
#
#   BLOCK>
#
#   BLOCK>                        coef 3 3 1.0
#
#   BLOCK>
#
#   BLOCK>                        excl 2 3
#  Number of block exclusions nblock_excldPairs=          42
#
#   BLOCK>
#
#   BLOCK>                        rmla bond thet impr
#  RMLAMBDA list
#   BOND T THETA T PHI F IMPHI T CMAPF UREY-BT
#
#   BLOCK>                        msma
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#
#   BLOCK>                  END
#  Matrix of Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of BOND Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of ANGLE Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of DIHE Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of CROSS Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of ELEC Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of VDW Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#
#  CHARMM>
#
#  VOPEN> Attempting to open::cond1/dcd/prod1.dcd::
#
#  CHARMM>     traj query unit 7
#
#  READING TRAJECTORY FROM UNIT   7
#    NUMBER OF COORDINATE SETS IN FILE:        1000
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:         1000
#
#    NUMBER OF DEGREES OF FREEDOM:              114
#    NUMBER OF FIXED ATOMS:                       0
#    THE INTEGRATION TIME STEP (PS):      0.0010
#    THE FILE CONTAINS CRYSTAL UNIT CELL DATA
#    THE FILE DOES NOT CONTAIN 4-D DATA
#
#
#  CHARMM>     traj firstu 7 nunit 1 skip 1
#  TRAJ: INITIATING READ OF A TRAJECTORY, OPTIONS;
#     FIRSTU =   7 NUNIT =   1 SKIP =     1
#
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# [stdout:4]  VOPEN> Attempting to open::aa4/out/prod1.out::
#
#  CHARMM>     outu 30
# A selection has been stored as SITELYS1SUBW
# A selection has been stored as SITELYS1SUBM
# A selection has been stored as SITELYS1SUBP
# A selection has been stored as SITELYS1SUBU
#
#  VCLOSE: Closing unit   30 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>                  BLOCK 3
#
#   BLOCK>                        clear
#  Block Structure has been turned off.
#
#   BLOCK>                  END
#
#  CHARMM>
#
#
#  CHARMM>
#
#  CHARMM>                  BLOCK 3
#  Block structure initialized with   3 blocks.
#  All atoms have been assigned to block 1.
#  All interaction coefficients have been set to unity.
#   Setting number of block exclusions nblock_excldPairs=0
#
#   BLOCK>                        call 2 sele siteLYS1subW end
#  SELRPN>      7 atoms have been selected out of     40
#  The selected atoms have been reassigned to block   2
#
#   BLOCK>                        call 3 sele siteLYS1subM end
#  SELRPN>      6 atoms have been selected out of     40
#  The selected atoms have been reassigned to block   3
#
#   BLOCK>
#
#   BLOCK>                        coef 1 1 1.0
#
#   BLOCK>                        coef 1 2 0.0
#
#   BLOCK>                        coef 1 3 1.0
#
#   BLOCK>
#
#   BLOCK>                        coef 2 2 0.0
#
#   BLOCK>                        coef 2 3 0.0
#
#   BLOCK>
#
#   BLOCK>                        coef 3 3 1.0
#
#   BLOCK>
#
#   BLOCK>                        excl 2 3
#  Number of block exclusions nblock_excldPairs=          42
#
#   BLOCK>
#
#   BLOCK>                        rmla bond thet impr
#  RMLAMBDA list
#   BOND T THETA T PHI F IMPHI T CMAPF UREY-BT
#
#   BLOCK>                        msma
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#
#   BLOCK>                  END
#  Matrix of Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of BOND Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of ANGLE Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of DIHE Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of CROSS Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of ELEC Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of VDW Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#
#  CHARMM>
#
#  VOPEN> Attempting to open::cond4/dcd/prod1.dcd::
#
#  CHARMM>     traj query unit 7
#
#  READING TRAJECTORY FROM UNIT   7
#    NUMBER OF COORDINATE SETS IN FILE:        1000
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:         1000
#
#    NUMBER OF DEGREES OF FREEDOM:              114
#    NUMBER OF FIXED ATOMS:                       0
#    THE INTEGRATION TIME STEP (PS):      0.0010
#    THE FILE CONTAINS CRYSTAL UNIT CELL DATA
#    THE FILE DOES NOT CONTAIN 4-D DATA
#
#
#  CHARMM>     traj firstu 7 nunit 1 skip 1
#  TRAJ: INITIATING READ OF A TRAJECTORY, OPTIONS;
#     FIRSTU =   7 NUNIT =   1 SKIP =     1
#
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# [stdout:6]  VOPEN> Attempting to open::aa6/out/prod1.out::
#
#  CHARMM>     outu 30
# A selection has been stored as SITELYS1SUBW
# A selection has been stored as SITELYS1SUBM
# A selection has been stored as SITELYS1SUBP
# A selection has been stored as SITELYS1SUBU
#
#  VCLOSE: Closing unit   30 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>                  BLOCK 3
#
#   BLOCK>                        clear
#  Block Structure has been turned off.
#
#   BLOCK>                  END
#
#  CHARMM>
#
#
#  CHARMM>
#
#  CHARMM>                  BLOCK 3
#  Block structure initialized with   3 blocks.
#  All atoms have been assigned to block 1.
#  All interaction coefficients have been set to unity.
#   Setting number of block exclusions nblock_excldPairs=0
#
#   BLOCK>                        call 2 sele siteLYS1subW end
#  SELRPN>      7 atoms have been selected out of     40
#  The selected atoms have been reassigned to block   2
#
#   BLOCK>                        call 3 sele siteLYS1subM end
#  SELRPN>      6 atoms have been selected out of     40
#  The selected atoms have been reassigned to block   3
#
#   BLOCK>
#
#   BLOCK>                        coef 1 1 1.0
#
#   BLOCK>                        coef 1 2 0.0
#
#   BLOCK>                        coef 1 3 1.0
#
#   BLOCK>
#
#   BLOCK>                        coef 2 2 0.0
#
#   BLOCK>                        coef 2 3 0.0
#
#   BLOCK>
#
#   BLOCK>                        coef 3 3 1.0
#
#   BLOCK>
#
#   BLOCK>                        excl 2 3
#  Number of block exclusions nblock_excldPairs=          42
#
#   BLOCK>
#
#   BLOCK>                        rmla bond thet impr
#  RMLAMBDA list
#   BOND T THETA T PHI F IMPHI T CMAPF UREY-BT
#
#   BLOCK>                        msma
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#
#   BLOCK>                  END
#  Matrix of Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of BOND Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of ANGLE Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of DIHE Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of CROSS Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of ELEC Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#  Matrix of VDW Interaction Coefficients
#
#     1.00000
#     0.00000   0.00000
#     1.00000   0.00000   1.00000
#
#  CHARMM>
#
#  VOPEN> Attempting to open::cond6/dcd/prod1.dcd::
#
#  CHARMM>     traj query unit 7
#
#  READING TRAJECTORY FROM UNIT   7
#    NUMBER OF COORDINATE SETS IN FILE:        1000
#    NUMBER OF PREVIOUS DYNAMICS STEPS:           1
#    FREQUENCY FOR SAVING COORDINATES:            1
#    NUMBER OF STEPS FOR CREATION RUN:         1000
#
#    NUMBER OF DEGREES OF FREEDOM:              114
#    NUMBER OF FIXED ATOMS:                       0
#    THE INTEGRATION TIME STEP (PS):      0.0010
#    THE FILE CONTAINS CRYSTAL UNIT CELL DATA
#    THE FILE DOES NOT CONTAIN 4-D DATA
#
#
#  CHARMM>     traj firstu 7 nunit 1 skip 1
#  TRAJ: INITIATING READ OF A TRAJECTORY, OPTIONS;
#     FIRSTU =   7 NUNIT =   1 SKIP =     1
#
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# WARNING: MLMA command ignored. MLMA must be invoked after MDLM.
#  *****  WARNING  ***** BEGIN=           0 Was not specified. It has been set to:           1
#  <MAKINB>: Ran out of space. RESIZING
# [stderr:0]  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# 8 errors
# mpiexec error output:
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   PID 28050 RUNNING AT MacBook-Pro-27.local
# =   EXIT CODE: 1
# =   CLEANING UP REMAINING PROCESSES
# =   YOU CAN IGNORE THE BELOW CLEANUP MESSAGES
# ===================================================================================
# YOUR APPLICATION TERMINATED WITH THE EXIT STRING: Hangup: 1 (signal 1)
#
# engine set stopped 1673300381: {'exit_code': 1, 'pid': 28042, 'identifier': 'ipengine-1673300380-kegu-1673300381-28022'}

# %% [markdown]
# ## Check results

# %% [markdown]
# ### File ```cnd_fn``` contains condition information (i.e., $\lambda$ here)

# %%
# !cat cond.dat
# Out:
# SETTING-UP CHARMM
# pyCHARMM w/o MPI library present, set CHARMM_LIB_DIR
# pyCHARMM w MPI library present, set CHARMM_LIB_DIR_mpi
# CHARMM present, set charmm
# Setting up MMSTB Tools
# Setting up MATCH
# Setting up BABEL stuff
# Setting up chimera
# Adding chemaxon
# Adding ssh agents
# Past case statement
# Past orca
# 0.0000
# 0.1429
# 0.2857
# 0.4286
# 0.5714
# 0.7143
# 0.8571
# 1.0000

# %% [markdown]
# ### Directories ```out_dir``` (aa* here) contain dcd files, charmm output file, etc, for each replica.
# ### Directories cond* contain dcd files, recomputed energies for each condition.

# %%
# !ls .
# Out:
# SETTING-UP CHARMM
# pyCHARMM w/o MPI library present, set CHARMM_LIB_DIR
# pyCHARMM w MPI library present, set CHARMM_LIB_DIR_mpi
# CHARMM present, set charmm
# Setting up MMSTB Tools
# Setting up MATCH
# Setting up BABEL stuff
# Setting up chimera
# Adding chemaxon
# Adding ssh agents
# Past case statement
# Past orca
# aa0                     cond.dat                exchange-all-1.dat
# aa1                     cond0                   fig
# aa2                     cond1                   lys.pdb
# aa3                     cond2                   lys.psf
# aa4                     cond3                   mbar.out
# aa5                     cond4                   ratio-1.dat
# aa6                     cond5                   rep_ex_amino_acid.ipynb
# aa7                     cond6                   rep_ex_amino_acid.py
# box_size.dat            cond7                   toppar

# %%
# !ls aa0 cond0
# Out:
# SETTING-UP CHARMM
# pyCHARMM w/o MPI library present, set CHARMM_LIB_DIR
# pyCHARMM w MPI library present, set CHARMM_LIB_DIR_mpi
# CHARMM present, set charmm
# Setting up MMSTB Tools
# Setting up MATCH
# Setting up BABEL stuff
# Setting up chimera
# Adding chemaxon
# Adding ssh agents
# Past case statement
# Past orca
# aa0:
# dcd      exc      his      init.pdb mini.pdb out      pdb      res
#
# cond0:
# dcd  ener

# %% [markdown]
# ### File ```ratio_fn``` (ratio-1.dat here) has exchange ratio for the current run.

# %%
! cat ratio-1.dat
# Out:
# SETTING-UP CHARMM
# pyCHARMM w/o MPI library present, set CHARMM_LIB_DIR
# pyCHARMM w MPI library present, set CHARMM_LIB_DIR_mpi
# CHARMM present, set charmm
# Setting up MMSTB Tools
# Setting up MATCH
# Setting up BABEL stuff
# Setting up chimera
# Adding chemaxon
# Adding ssh agents
# Past case statement
# Past orca
# 0.000000 1.000000 278.000000 500.000000 0.556000
# 1.000000 2.000000 160.000000 500.000000 0.320000
# 2.000000 3.000000 200.000000 500.000000 0.400000
# 3.000000 4.000000 318.000000 500.000000 0.636000
# 4.000000 5.000000 316.000000 500.000000 0.632000
# 5.000000 6.000000 296.000000 500.000000 0.592000
# 6.000000 7.000000 199.000000 500.000000 0.398000

# %% [markdown]
# ### Check $\lambda$ as a function of simulation time for a given replica. From this, we can check how well replicas could perform random walk in $\lambda$ space.

# %%
import numpy as np
import matplotlib.pyplot as plt
i=7
fn='aa'+str(i)+'/his/cond_his1.dat'
l=np.loadtxt(fn)
plt.xlabel('Cycle Index')
plt.ylabel('$\lambda$')
plt.title('Replica '+str(i))
plt.plot(l[:,0],l[:,1])

# %% [markdown]
# ### Free energy profile ```fe_fn``` (mbar.out here): the 1st column is $\lambda$; the 2nd column is free energy, and the 3rd column is the error bar

# %%
# !cat mbar.out
# Out:
# SETTING-UP CHARMM
# pyCHARMM w/o MPI library present, set CHARMM_LIB_DIR
# pyCHARMM w MPI library present, set CHARMM_LIB_DIR_mpi
# CHARMM present, set charmm
# Setting up MMSTB Tools
# Setting up MATCH
# Setting up BABEL stuff
# Setting up chimera
# Adding chemaxon
# Adding ssh agents
# Past case statement
# Past orca
# 0.000000 0.000000 0.000000
# 0.142900 1.592999 0.006648
# 0.285700 2.423044 0.019283
# 0.428600 2.032620 0.030730
# 0.571400 1.106288 0.033734
# 0.714300 -0.092650 0.036285
# 0.857100 -1.573468 0.037570
# 1.000000 -3.542143 0.039832
